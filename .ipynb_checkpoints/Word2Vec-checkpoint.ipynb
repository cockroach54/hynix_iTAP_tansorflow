# %% [markdown]
# # Word Embedding example
#  - 단어를 벡터로 표현하는 방법
# > - https://tensorflowkorea.gitbooks.io/tensorflow-kr/content/g3doc/tutorials/word2vec/
# - http://solarisailab.com/archives/374

# %% [markdown]
# ---
# ## Tensorflow로 직접 만들기

# %%
# -*- coding: utf-8 -*-

# 절대 임포트 설정
from __future__ import absolute_import
from __future__ import print_function

# 필요한 라이브러리들을 임포트
import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: 필요한 데이터를 다운로드한다.
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """파일이 존재하지 않으면 다운로드하고 사이즈가 적절한지 체크한다."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('corpus/text8.zip', 31344016)

# 문자열로 데이터를 읽는다
def read_data(filename):
  """zip파일 압축을 해제하고 단어들의 리스트를 읽는다."""
  with zipfile.ZipFile(filename) as f:
    data = f.read(f.namelist()[0]).split()
  return data

words = read_data(filename)
print('Data size', len(words))
# Out:
# Found and verified corpus/text8.zip
# Data size 17005207

# %%
# Step 2: dictionary를 만들고 UNK 토큰을 이용해서 rare words를 교체(replace)한다.
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], (b'the', 1061396), (b'of', 593677), (b'and', 416629), (b'one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] [b'anarchism', b'originated', b'as', b'a', b'term', b'of', b'abuse', b'first', b'used', b'against']

# %%
# Step 3: skip-gram model을 위한 트레이닝 데이터(batch)를 생성하기 위한 함수.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
      '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 b'originated' -> 12 b'as'
# 3081 b'originated' -> 5234 b'anarchism'
# 12 b'as' -> 3081 b'originated'
# 12 b'as' -> 6 b'a'
# 6 b'a' -> 195 b'term'
# 6 b'a' -> 12 b'as'
# 195 b'term' -> 2 b'of'
# 195 b'term' -> 6 b'a'

# %%
# Step 4: skip-gram model 만들고 학습시킨다.

batch_size = 128
embedding_size = 128  # embedding vector의 크기.
skip_window = 1       # 윈도우 크기 : 왼쪽과 오른쪽으로 얼마나 많은 단어를 고려할지를 결정.
num_skips = 2         # 레이블(label)을 생성하기 위해 인풋을 얼마나 많이 재사용 할 것인지를 결정.

# sample에 대한 validation set은 원래 랜덤하게 선택해야한다. 하지만 여기서는 validation samples을 
# 가장 자주 생성되고 낮은 숫자의 ID를 가진 단어로 제한한다.
valid_size = 16     # validation 사이즈.
valid_window = 100  # 분포의 앞부분(head of the distribution)에서만 validation sample을 선택한다.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # sample에 대한 negative examples의 개수.

graph = tf.Graph()

with graph.as_default():

  # 트레이닝을 위한 인풋 데이터들
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # embedding vectors 행렬을 랜덤값으로 초기화
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    # 행렬에 트레이닝 데이터를 지정
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # NCE loss를 위한 변수들을 선언
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # batch의 average NCE loss를 계산한다.
  # tf.nce_loss 함수는 loss를 평가(evaluate)할 때마다 negative labels을 가진 새로운 샘플을 자동적으로 생성한다.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # SGD optimizer를 생성한다.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # minibatch examples과 모든 embeddings에 대해 cosine similarity를 계산한다.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
# Step 5: 트레이닝을 시작한다.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # 트레이닝을 시작하기 전에 모든 변수들을 초기화한다.
  tf.initialize_all_variables().run()
  print("Initialized")

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

    # optimizer op을 평가(evaluating)하면서 한 스텝 업데이트를 진행한다.
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # 평균 손실(average loss)은 지난 2000 배치의 손실(loss)로부터 측정된다.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # nearest neighbors의 개수
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-33-8b286c4049eb>:6: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step  0 :  280.712768555
# Nearest to b'five': b'osborn', b'konerko', b'redskins', b'vaccine', b'mediawiki', b'manatee', b'mcdowell', b'swordsmanship',
# Nearest to b'they': b'alec', b'hone', b'haq', b'nonexistence', b'tatra', b'ie', b'animists', b'strangely',
# Nearest to b'all': b'turkey', b'intersected', b'escuela', b'recombinant', b'inning', b'snafu', b'solvable', b'wares',
# Nearest to b'be': b'weasels', b'nerve', b'threatening', b'judaic', b'rainforest', b'kc', b'nitrite', b'lans',
# Nearest to b'in': b'massive', b'pictish', b'restricts', b'instalments', b'crux', b'coulter', b'consideration', b'covariance',
# Nearest to UNK: b'porting', b'financial', b'quantum', b'wolfhounds', b'rb', b'consumers', b'senescence', b'cayce',
# Nearest to b'have': b'stalinism', b'horribly', b'bcl', b'conceits', b'conserve', b'reachable', b'inexpensive', b'cyril',
# Nearest to b'he': b'lads', b'championed', b'convenes', b'bellini', b'desegregation', b'romantics', b'genomes', b'chairman',
# Nearest to b'that': b'hilary', b'rdoba', b'uttered', b'eschatological', b'astronautics', b'chattel', b'ogdoad', b'vance',
# Nearest to b's': b'lynch', b'ane', b'provincias', b'coler', b'pleasing', b'torres', b'jodie', b'involvement',
# Nearest to b'but': b'normally', b'pointers', b'rewritable', b'hay', b'patronage', b'sidewise', b'flavored', b'spiny',
# Nearest to b'can': b'bhaskara', b'managerial', b'wiped', b'bt', b'merlin', b'poitiers', b'frodo', b'tenor',
# Nearest to b'this': b'cuthbert', b'strut', b'addison', b'conner', b'epidemics', b'harboring', b'mya', b'bight',
# Nearest to b'called': b'lone', b'dvds', b'jays', b'angles', b'fusion', b'specially', b'daemons', b'chronometer',
# Nearest to b'such': b'ensues', b'airflow', b'unorganized', b'sympathized', b'boziz', b'revolting', b'diacritical', b'dual',
# Nearest to b'nine': b'acadia', b'booty', b'motivation', b'joss', b'brummell', b'perro', b'errands', b'perpetuity',
# Average loss at step  2000 :  114.427333809
# Average loss at step  4000 :  52.4461870477
# Average loss at step  6000 :  33.1468718424
# Average loss at step  8000 :  23.5973158863
# Average loss at step  10000 :  17.9077697864
# Nearest to b'five': b'zero', b'victoriae', b'nine', b'reginae', b'hoare', b'orbital', b'eight', b'agave',
# Nearest to b'they': b'he', b'it', b'and', b'made', b'canaris', b'unprotected', b'badges', b'scrimmage',
# Nearest to b'all': b'turkey', b'yard', b'results', b'live', b'emma', b'coordination', b'cl', b'mp',
# Nearest to b'be': b'only', b'loves', b'nerve', b'trembling', b'have', b'as', b'threatening', b'analogue',
# Nearest to b'in': b'and', b'of', b'on', b'for', b'as', b'from', b'reginae', b'one',
# Nearest to UNK: b'and', b'gland', b'one', b'two', b'cl', b'the', b'agave', b'vs',
# Nearest to b'have': b'stalinism', b'kasparov', b'by', b'nation', b'be', b'peninsula', b'bipedalism', b'asphalt',
# Nearest to b'he': b'canaris', b'they', b'halo', b'and', b'some', b'it', b'an', b'altenberg',
# Nearest to b'that': b'and', b'criticise', b'which', b'vs', b'beach', b'rdoba', b'conclusion', b'byzantine',
# Nearest to b's': b'and', b'analogue', b'one', b'seed', b'choice', b'of', b'provincias', b'badges',
# Nearest to b'but': b'your', b'vs', b'and', b'reginae', b'indirectly', b'two', b'phi', b'somme',
# Nearest to b'can': b'laureate', b'powerpc', b'vs', b'rocket', b'fill', b'cl', b'analogue', b'beyond',
# Nearest to b'this': b'the', b'a', b'amo', b'volunteers', b'given', b'quadrilateral', b'wayne', b'which',
# Nearest to b'called': b'angles', b'means', b'lone', b'discipline', b'ambients', b'dvds', b'lectures', b'fusion',
# Nearest to b'such': b'discovery', b'unorganized', b'theme', b'significantly', b'dual', b'nominee', b'victoriae', b'kilda',
# Nearest to b'nine': b'zero', b'reginae', b'victoriae', b'fao', b'eight', b'vs', b'phi', b'analogue',
# Average loss at step  12000 :  13.9906801599
# Average loss at step  14000 :  11.9684284807
# Average loss at step  16000 :  9.82030420649
# Average loss at step  18000 :  8.51606753898
# Average loss at step  20000 :  7.75325152552
# Nearest to b'five': b'eight', b'nine', b'zero', b'six', b'four', b'three', b'two', b'seven',
# Nearest to b'they': b'he', b'it', b'haq', b'castlevania', b'strangely', b'and', b'canaris', b'made',
# Nearest to b'all': b'turkey', b'adder', b'yard', b'results', b'live', b'ignored', b'coordination', b'wounded',
# Nearest to b'be': b'have', b'is', b'trembling', b'as', b'only', b'by', b'was', b'loves',
# Nearest to b'in': b'and', b'of', b'on', b'at', b'with', b'from', b'for', b'by',
# Nearest to UNK: b'agouti', b'dasyprocta', b'absalom', b'and', b'gland', b'cl', b'aquila', b'three',
# Nearest to b'have': b'be', b'were', b'by', b'stalinism', b'aquila', b'kasparov', b'dasyprocta', b'had',
# Nearest to b'he': b'it', b'they', b'cinque', b'canaris', b'who', b'and', b'adder', b'dasyprocta',
# Nearest to b'that': b'which', b'criticise', b'this', b'byzantine', b'vs', b'for', b'dasyprocta', b'and',
# Nearest to b's': b'zero', b'and', b'analogue', b'two', b'of', b'seed', b'falling', b'his',
# Nearest to b'but': b'and', b'vs', b'two', b'dasyprocta', b'is', b'that', b'phi', b'codified',
# Nearest to b'can': b'laureate', b'would', b'will', b'rocket', b'powerpc', b'vs', b'fill', b'thief',
# Nearest to b'this': b'it', b'a', b'the', b'which', b'that', b'volunteers', b'amo', b'one',
# Nearest to b'called': b'lone', b'angles', b'discipline', b'fusion', b'lectures', b'dvds', b'means', b'ambients',
# Nearest to b'such': b'discovery', b'significantly', b'revolting', b'nominee', b'theme', b'unorganized', b'calculated', b'a',
# Nearest to b'nine': b'eight', b'six', b'seven', b'zero', b'five', b'four', b'three', b'victoriae',
# Average loss at step  22000 :  7.22509091365
# Average loss at step  24000 :  6.96369390881
# Average loss at step  26000 :  6.68563118041
# Average loss at step  28000 :  6.19124413264
# Average loss at step  30000 :  6.16521363771
# Nearest to b'five': b'eight', b'four', b'six', b'three', b'seven', b'nine', b'zero', b'two',
# Nearest to b'they': b'he', b'it', b'we', b'haq', b'there', b'these', b'she', b'castlevania',
# Nearest to b'all': b'turkey', b'adder', b'amalthea', b'yard', b'most', b'some', b'ignored', b'live',
# Nearest to b'be': b'have', b'is', b'by', b'trembling', b'as', b'was', b'only', b'loves',
# Nearest to b'in': b'and', b'on', b'at', b'from', b'of', b'nine', b'by', b'for',
# Nearest to UNK: b'agouti', b'dasyprocta', b'abet', b'absalom', b'amalthea', b'two', b'aorta', b'victoriae',
# Nearest to b'have': b'be', b'had', b'were', b'has', b'are', b'by', b'stalinism', b'aquila',
# Nearest to b'he': b'it', b'they', b'she', b'who', b'and', b'cinque', b'there', b'canaris',
# Nearest to b'that': b'which', b'but', b'this', b'criticise', b'designate', b'abitibi', b'aediles', b'vs',
# Nearest to b's': b'and', b'zero', b'of', b'two', b'his', b'morita', b'analogue', b'four',
# Nearest to b'but': b'and', b'that', b'vs', b'which', b'is', b'amalthea', b'dasyprocta', b'although',
# Nearest to b'can': b'would', b'will', b'may', b'laureate', b'to', b'vs', b'are', b'thief',
# Nearest to b'this': b'which', b'it', b'the', b'a', b'that', b'another', b'adder', b'its',
# Nearest to b'called': b'lone', b'angles', b'oath', b'dvds', b'discipline', b'ambients', b'revolted', b'abitibi',
# Nearest to b'such': b'well', b'airflow', b'discovery', b'arnulf', b'revolting', b'garc', b'significantly', b'unorganized',
# Nearest to b'nine': b'eight', b'six', b'seven', b'five', b'four', b'three', b'zero', b'victoriae',
# Average loss at step  32000 :  5.83933114231
# Average loss at step  34000 :  5.8784683001
# Average loss at step  36000 :  5.69828106666
# Average loss at step  38000 :  5.26892933929
# Average loss at step  40000 :  5.4474946003
# Nearest to b'five': b'four', b'six', b'three', b'seven', b'eight', b'zero', b'nine', b'two',
# Nearest to b'they': b'he', b'it', b'we', b'there', b'she', b'these', b'haq', b'not',
# Nearest to b'all': b'turkey', b'adder', b'amalthea', b'some', b'cl', b'these', b'results', b'two',
# Nearest to b'be': b'have', b'by', b'was', b'is', b'trembling', b'were', b'been', b'as',
# Nearest to b'in': b'and', b'on', b'from', b'at', b'of', b'dasyprocta', b'aorta', b'with',
# Nearest to UNK: b'agouti', b'dasyprocta', b'absalom', b'aorta', b'and', b'abet', b'one', b'altenberg',
# Nearest to b'have': b'were', b'has', b'had', b'be', b'are', b'by', b'stalinism', b'wop',
# Nearest to b'he': b'it', b'they', b'she', b'who', b'cinque', b'there', b'lads', b'canaris',
# Nearest to b'that': b'which', b'this', b'but', b'it', b'criticise', b'abitibi', b'aediles', b'however',
# Nearest to b's': b'and', b'his', b'falling', b'imran', b'choice', b'zero', b'dasyprocta', b'two',
# Nearest to b'but': b'and', b'which', b'that', b'four', b'although', b'it', b'dasyprocta', b'vs',
# Nearest to b'can': b'would', b'will', b'may', b'could', b'to', b'laureate', b'might', b'should',
# Nearest to b'this': b'which', b'the', b'it', b'that', b'a', b'another', b'its', b'given',
# Nearest to b'called': b'oath', b'lone', b'and', b'hrothgar', b'discipline', b'against', b'dvds', b'goo',
# Nearest to b'such': b'well', b'airflow', b'discovery', b'arnulf', b'revolting', b'garc', b'particularly', b'druyan',
# Nearest to b'nine': b'eight', b'six', b'seven', b'five', b'zero', b'four', b'three', b'victoriae',
# Average loss at step  42000 :  5.30714645898
# Average loss at step  44000 :  5.28158456278
# Average loss at step  46000 :  5.24940261233
# Average loss at step  48000 :  5.02421320891
# Average loss at step  50000 :  5.14558829856
# Nearest to b'five': b'four', b'six', b'three', b'eight', b'seven', b'zero', b'two', b'nine',
# Nearest to b'they': b'he', b'it', b'we', b'there', b'she', b'you', b'who', b'not',
# Nearest to b'all': b'turkey', b'some', b'adder', b'two', b'amalthea', b'these', b'cl', b'both',
# Nearest to b'be': b'have', b'by', b'was', b'were', b'is', b'been', b'are', b'trembling',
# Nearest to b'in': b'on', b'at', b'and', b'from', b'of', b'nine', b'during', b'dasyprocta',
# Nearest to UNK: b'agouti', b'dasyprocta', b'altenberg', b'thibetanus', b'four', b'naaman', b'victoriae', b'reginae',
# Nearest to b'have': b'had', b'has', b'were', b'be', b'are', b'stalinism', b'by', b'wop',
# Nearest to b'he': b'it', b'they', b'she', b'who', b'there', b'lads', b'cinque', b'operatorname',
# Nearest to b'that': b'which', b'this', b'but', b'criticise', b'however', b'it', b'designate', b'abitibi',
# Nearest to b's': b'his', b'and', b'falling', b'zero', b'dasyprocta', b'agave', b'morita', b'was',
# Nearest to b'but': b'and', b'which', b'however', b'although', b'dasyprocta', b'that', b'amalthea', b'four',
# Nearest to b'can': b'would', b'will', b'may', b'could', b'should', b'might', b'to', b'laureate',
# Nearest to b'this': b'which', b'it', b'the', b'that', b'another', b'solicitation', b'a', b'adder',
# Nearest to b'called': b'oath', b'discipline', b'lone', b'hrothgar', b'abitibi', b'goo', b'ambients', b'against',
# Nearest to b'such': b'well', b'airflow', b'arnulf', b'discovery', b'lc', b'revolting', b'lorenz', b'particularly',
# Nearest to b'nine': b'eight', b'seven', b'six', b'three', b'five', b'zero', b'four', b'reginae',
# Average loss at step  52000 :  5.16376301897
# Average loss at step  54000 :  5.11115773773
# Average loss at step  56000 :  5.0516986419
# Average loss at step  58000 :  5.10716897345
# Average loss at step  60000 :  4.95263117796
# Nearest to b'five': b'four', b'six', b'three', b'eight', b'seven', b'zero', b'nine', b'two',
# Nearest to b'they': b'he', b'it', b'we', b'there', b'you', b'she', b'not', b'these',
# Nearest to b'all': b'some', b'these', b'turkey', b'many', b'both', b'adder', b'amalthea', b'callithrix',
# Nearest to b'be': b'have', b'by', b'been', b'was', b'is', b'were', b'are', b'callithrix',
# Nearest to b'in': b'at', b'on', b'and', b'of', b'callithrix', b'microsite', b'from', b'microcebus',
# Nearest to UNK: b'agouti', b'marmoset', b'ssbn', b'michelob', b'dasyprocta', b'microcebus', b'callithrix', b'cebus',
# Nearest to b'have': b'had', b'has', b'were', b'are', b'be', b'callithrix', b'stalinism', b'aquila',
# Nearest to b'he': b'it', b'they', b'she', b'who', b'there', b'lads', b'cinque', b'spectrometer',
# Nearest to b'that': b'which', b'this', b'but', b'however', b'criticise', b'it', b'microcebus', b'tamarin',
# Nearest to b's': b'his', b'zero', b'callithrix', b'and', b'falling', b'choice', b'dasyprocta', b'morita',
# Nearest to b'but': b'and', b'however', b'which', b'although', b'tamarin', b'ssbn', b'dasyprocta', b'or',
# Nearest to b'can': b'would', b'will', b'may', b'could', b'should', b'might', b'must', b'to',
# Nearest to b'this': b'which', b'it', b'the', b'that', b'another', b'solicitation', b'tamarin', b'aquifer',
# Nearest to b'called': b'oath', b'lone', b'discipline', b'hrothgar', b'jays', b'abitibi', b'against', b'named',
# Nearest to b'such': b'well', b'capuchin', b'arnulf', b'tamarin', b'airflow', b'these', b'lorenz', b'particularly',
# Nearest to b'nine': b'eight', b'six', b'seven', b'four', b'five', b'zero', b'three', b'callithrix',
# Average loss at step  62000 :  4.79856666958
# Average loss at step  64000 :  4.78531875372
# Average loss at step  66000 :  4.99105813098
# Average loss at step  68000 :  4.91490933204
# Average loss at step  70000 :  4.78913145864
# Nearest to b'five': b'four', b'six', b'eight', b'three', b'seven', b'nine', b'zero', b'two',
# Nearest to b'they': b'he', b'we', b'it', b'there', b'you', b'she', b'these', b'who',
# Nearest to b'all': b'some', b'these', b'many', b'both', b'turkey', b'thaler', b'adder', b'amalthea',
# Nearest to b'be': b'been', b'have', b'by', b'were', b'is', b'was', b'are', b'callithrix',
# Nearest to b'in': b'at', b'callithrix', b'on', b'within', b'microsite', b'dasyprocta', b'upanija', b'from',
# Nearest to UNK: b'thaler', b'agouti', b'cebus', b'michelob', b'microcebus', b'dasyprocta', b'ssbn', b'marmoset',
# Nearest to b'have': b'had', b'has', b'were', b'are', b'be', b'callithrix', b'stalinism', b'aquila',
# Nearest to b'he': b'it', b'they', b'she', b'who', b'there', b'lads', b'cinque', b'spectrometer',
# Nearest to b'that': b'which', b'this', b'but', b'however', b'thaler', b'it', b'criticise', b'upanija',
# Nearest to b's': b'callithrix', b'falling', b'mitral', b'his', b'choice', b'agave', b'dasyprocta', b'and',
# Nearest to b'but': b'and', b'however', b'which', b'thaler', b'although', b'dasyprocta', b'that', b'upanija',
# Nearest to b'can': b'may', b'would', b'will', b'could', b'should', b'might', b'must', b'to',
# Nearest to b'this': b'which', b'it', b'the', b'that', b'another', b'solicitation', b'tamarin', b'one',
# Nearest to b'called': b'oath', b'thaler', b'named', b'discipline', b'against', b'lone', b'jays', b'hrothgar',
# Nearest to b'such': b'well', b'these', b'many', b'capuchin', b'arnulf', b'tamarin', b'including', b'airflow',
# Nearest to b'nine': b'eight', b'six', b'seven', b'five', b'zero', b'four', b'three', b'callithrix',
# Average loss at step  72000 :  4.81368554676
# Average loss at step  74000 :  4.77753735083
# Average loss at step  76000 :  4.89327566743
# Average loss at step  78000 :  4.78390913785
# Average loss at step  80000 :  4.8232268852
# Nearest to b'five': b'six', b'four', b'seven', b'eight', b'three', b'nine', b'two', b'zero',
# Nearest to b'they': b'he', b'we', b'there', b'it', b'you', b'she', b'these', b'who',
# Nearest to b'all': b'some', b'many', b'these', b'both', b'thaler', b'turkey', b'adder', b'escuela',
# Nearest to b'be': b'been', b'have', b'by', b'were', b'was', b'is', b'callithrix', b'are',
# Nearest to b'in': b'during', b'at', b'on', b'and', b'under', b'nine', b'dasyprocta', b'microsite',
# Nearest to UNK: b'agouti', b'marmoset', b'thaler', b'cebus', b'michelob', b'clodius', b'saguinus', b'microcebus',
# Nearest to b'have': b'had', b'has', b'were', b'are', b'be', b'callithrix', b'stalinism', b'wop',
# Nearest to b'he': b'it', b'she', b'they', b'who', b'there', b'lads', b'cinque', b'spectrometer',
# Nearest to b'that': b'which', b'this', b'however', b'but', b'thaler', b'upanija', b'criticise', b'somehow',
# Nearest to b's': b'zero', b'callithrix', b'falling', b'mitral', b'his', b'choice', b'techs', b'morita',
# Nearest to b'but': b'and', b'however', b'although', b'thaler', b'which', b'or', b'dasyprocta', b'upanija',
# Nearest to b'can': b'may', b'will', b'would', b'could', b'should', b'might', b'must', b'cannot',
# Nearest to b'this': b'which', b'it', b'the', b'that', b'another', b'one', b'solicitation', b'tamarin',
# Nearest to b'called': b'named', b'oath', b'thaler', b'clodius', b'against', b'microcebus', b'discipline', b'abitibi',
# Nearest to b'such': b'these', b'well', b'many', b'tamarin', b'including', b'capuchin', b'clo', b'arnulf',
# Nearest to b'nine': b'eight', b'seven', b'six', b'five', b'four', b'zero', b'three', b'callithrix',
# Average loss at step  82000 :  4.80429049909
# Average loss at step  84000 :  4.7807950685
# Average loss at step  86000 :  4.75875095105
# Average loss at step  88000 :  4.68982870293
# Average loss at step  90000 :  4.77474622595
# Nearest to b'five': b'four', b'eight', b'seven', b'six', b'three', b'nine', b'two', b'zero',
# Nearest to b'they': b'he', b'we', b'there', b'it', b'you', b'she', b'these', b'not',
# Nearest to b'all': b'some', b'both', b'these', b'many', b'thaler', b'turkey', b'escuela', b'adder',
# Nearest to b'be': b'been', b'have', b'was', b'is', b'by', b'were', b'are', b'callithrix',
# Nearest to b'in': b'at', b'during', b'of', b'under', b'within', b'and', b'on', b'dasyprocta',
# Nearest to UNK: b'thaler', b'agouti', b'cebus', b'clodius', b'michelob', b'microcebus', b'callithrix', b'tamarin',
# Nearest to b'have': b'had', b'has', b'are', b'were', b'be', b'callithrix', b'stalinism', b'aquila',
# Nearest to b'he': b'it', b'she', b'they', b'who', b'there', b'cinque', b'lads', b'spectrometer',
# Nearest to b'that': b'which', b'however', b'but', b'this', b'thaler', b'upanija', b'criticise', b'pidgin',
# Nearest to b's': b'falling', b'his', b'zero', b'callithrix', b'and', b'morita', b'mitral', b'torres',
# Nearest to b'but': b'and', b'however', b'although', b'which', b'thaler', b'or', b'while', b'upanija',
# Nearest to b'can': b'may', b'will', b'would', b'could', b'should', b'might', b'must', b'cannot',
# Nearest to b'this': b'which', b'it', b'the', b'another', b'that', b'tamarin', b'solicitation', b'some',
# Nearest to b'called': b'named', b'oath', b'thaler', b'clodius', b'microcebus', b'against', b'abitibi', b'chittagong',
# Nearest to b'such': b'these', b'well', b'many', b'including', b'known', b'some', b'seen', b'arnulf',
# Nearest to b'nine': b'eight', b'seven', b'six', b'five', b'four', b'zero', b'callithrix', b'three',
# Average loss at step  92000 :  4.70590117693
# Average loss at step  94000 :  4.62205260766
# Average loss at step  96000 :  4.71423360395
# Average loss at step  98000 :  4.6151013999
# Average loss at step  100000 :  4.68708640409
# Nearest to b'five': b'four', b'six', b'seven', b'eight', b'three', b'zero', b'nine', b'two',
# Nearest to b'they': b'he', b'we', b'there', b'you', b'she', b'it', b'these', b'not',
# Nearest to b'all': b'these', b'both', b'many', b'some', b'thaler', b'escuela', b'turkey', b'various',
# Nearest to b'be': b'been', b'have', b'by', b'is', b'being', b'are', b'was', b'were',
# Nearest to b'in': b'during', b'at', b'within', b'on', b'under', b'from', b'callithrix', b'and',
# Nearest to UNK: b'thaler', b'agouti', b'cebus', b'michelob', b'clodius', b'microcebus', b'abet', b'marmoset',
# Nearest to b'have': b'had', b'has', b'are', b'were', b'be', b'callithrix', b'wop', b'stalinism',
# Nearest to b'he': b'she', b'it', b'they', b'who', b'there', b'cinque', b'lads', b'pidgin',
# Nearest to b'that': b'which', b'however', b'this', b'but', b'criticise', b'upanija', b'thaler', b'what',
# Nearest to b's': b'his', b'falling', b'callithrix', b'the', b'morita', b'was', b'naaman', b'mitral',
# Nearest to b'but': b'and', b'however', b'although', b'while', b'which', b'thaler', b'when', b'upanija',
# Nearest to b'can': b'may', b'will', b'would', b'could', b'should', b'might', b'must', b'cannot',
# Nearest to b'this': b'which', b'it', b'the', b'that', b'another', b'some', b'solicitation', b'tamarin',
# Nearest to b'called': b'named', b'oath', b'thaler', b'clodius', b'and', b'microcebus', b'chittagong', b'against',
# Nearest to b'such': b'these', b'well', b'many', b'known', b'including', b'some', b'arnulf', b'seen',
# Nearest to b'nine': b'eight', b'seven', b'six', b'five', b'four', b'zero', b'three', b'callithrix',

# %%
# Step 6: embeddings을 시각화한다.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.show() # 파일로 저장하려면 이 줄 주석처리 후 아랫줄 주석해제 
#   plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")

# %% [markdown]
# ---
# ## Use Gensim library
# > - https://radimrehurek.com/gensim/models/word2vec.html

# %%
import nltk
# Download ancillary nltk packages if not already installed
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

# %%
# stopwords 셋팅
stops = [s for s in stopwords.words('english')]

# stemmer 셋팅
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
# nltk brown corpus 가져오기
brown = nltk.corpus.brown
sentences = []

# 원하는 코퍼스만 지정해서 가져올 경우  
# sentences = brown.sents(categories='fiction')
# sentences += brown.sents(categories='adventure')
# sentences += brown.sents(categories='romance')

# 모든 코퍼스 한번에 가져올 경우
for c in brown.categories():
    sentences += brown.sents(categories=c)

print(len(sentences))
# Out:
# 57340

# %%
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
# 비단어 모두 제외하는 정규식을 이용한 토크나이저 
t = RegexpTokenizer("[A-Za-z]+")

# 그냥 비문자 제거하고 소문자화만
tokenized = []
for sentence in sentences:
    tokenized.append(t.tokenize(' '.join([w.lower() for w in sentence if t not in stops])))

# %%
# stopwords 제거 및 stemming
# 여기선 사용안함 
stemmed = []
for sentence in sentences:
    stemmed.append([stemmer.stem(t) for t in sentence if t not in stops])

# %%
print(sentences[100])
print(tokenized[100])
# Out:
# ["We'll", 'work', 'hard', ',', 'Mr.', 'Morgan', "''", '.']
# ['we', 'll', 'work', 'hard', 'mr', 'morgan']

# %%
from gensim import models
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:862: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# word2vec model 1회만 간단히 학습할때
# model = models.Word2Vec(tokenized, size=100, window=7, min_count=5)

# %%
# %%time
# 너무 sparse하면 또 학습이 잘 안됨 100~300정도가 적당...
size=100
model = models.Word2Vec(size=size, window=7, min_count=1, workers=8,alpha=0.025, min_alpha=0.025)

model.build_vocab(tokenized) # 오로지 한번만 스트럭팅 가능

# learning_rate를 낮춰가며 여러번 트레이닝
for epoch in range(15):
    if epoch%1 ==0:
        print('epoch:',epoch, 'train completed')
    model.train(tokenized, total_examples=model.corpus_count, epochs=model.iter)
    model.alpha -= 0.002  # decrease the learning rate
    model.min_alpha = model.alpha  # fix the learning rate, no decay
# Out:
# epoch: 0 train completed
# epoch: 1 train completed
# epoch: 2 train completed
# epoch: 3 train completed
# epoch: 4 train completed
# epoch: 5 train completed
# epoch: 6 train completed
# epoch: 7 train completed
# epoch: 8 train completed
# epoch: 9 train completed
# epoch: 10 train completed
# epoch: 11 train completed
# epoch: 12 train completed
# epoch: 13 train completed
# epoch: 14 train completed
# Wall time: 31.6 s

# %%
model['good']
# Out:
# array([ 4.01027822,  0.72492093, -3.17885852, -2.64946747,  0.49794614,
#         0.59753752,  0.23797654, -3.23588681, -0.38208583,  0.80716479,
#        -0.01016903, -1.84569931, -0.82126981, -0.48096856, -2.08726716,
#         1.80586505, -0.62738001, -3.57415056, -1.9067142 , -0.89073598,
#        -5.12978601, -3.32113576,  3.2887001 ,  0.19433598, -1.90931213,
#         0.13779855,  1.1213187 ,  3.58784389,  1.56744218, -0.31708673,
#        -2.65861273,  0.87217653,  2.4508934 ,  3.92511272, -0.59954399,
#         0.18727383, -1.67664087, -1.00242746,  0.25556552,  1.34364545,
#         0.60805392,  0.97040081,  2.24735808,  0.56950676, -0.48994109,
#         1.63430882, -1.33950841,  1.79246104, -2.97347689,  3.359097  ,
#        -0.88870412,  1.78835869,  0.73786813,  1.32318532,  2.45174837,
#        -5.56448746,  1.46180046,  0.85183752, -1.84840715,  1.25602484,
#        -4.97478962,  1.30532479,  0.65671438, -0.95260143, -3.21400619,
#         3.29438615,  2.45088935, -1.98586786,  2.19092512,  2.61502671,
#         0.37615159, -3.53700948, -4.46205235, -3.16175389, -0.9268629 ,
#         1.66686594, -1.85794628, -1.08498049,  2.23868966,  0.11895506,
#         2.53478146, -0.30772275,  1.32310462, -0.84352279,  0.98046821,
#        -1.3190676 ,  1.25085223,  2.10858846,  2.37456369,  1.10368133,
#         0.72872931, -1.04194164,  3.1703012 ,  0.91690767,  0.51901925,
#        -1.04522133,  1.24578321,  1.30334544, -1.75015485,  1.52867711], dtype=float32)

# %%
model.most_similar('cup')
# Out:
# [('butter', 0.671150267124176),
#  ('onion', 0.6662799119949341),
#  ('salt', 0.6372348070144653),
#  ('sauce', 0.635702908039093),
#  ('tablespoonful', 0.6280929446220398),
#  ('pepper', 0.623282790184021),
#  ('teaspoon', 0.6162480711936951),
#  ('minced', 0.5965409278869629),
#  ('chives', 0.5782169103622437),
#  ('milk', 0.5738569498062134)]

# %%
model.wv.most_similar(positive=['woman', 'he'], negative=['man'])
# Out:
# [('she', 0.797360897064209),
#  ('i', 0.5839653015136719),
#  ('girl', 0.5782429575920105),
#  ('her', 0.5643243193626404),
#  ('henrietta', 0.5365340709686279),
#  ('lucy', 0.5117747187614441),
#  ('it', 0.5028141140937805),
#  ('miss', 0.49668729305267334),
#  ('they', 0.49350905418395996),
#  ('who', 0.49293801188468933)]

# %%
model.similarity('her', 'him')
# Out:
# 0.61241562035631869

# %% [markdown]
# ---
# ## 한국어 embedding
# - Naver movie review
# > - https://github.com/e9t/nsmc
#  - https://datascienceschool.net/view-notebook/6927b0906f884a67b0da9310d3a581ee/
#  - http://konlpy-ko.readthedocs.io

# %%
import csv
from pprint import pprint

# tsv load
with open('corpus/naver_movie_corpus/ratings_train.txt', 'r', encoding='utf-8') as f:
    rdr = csv.reader(f, delimiter='\t')
    naver_train = list(rdr)
    naver_train = [s[1] for s in naver_train[1:]]
    
with open('corpus/naver_movie_corpus/ratings_test.txt', 'r', encoding='utf-8') as f:
    rdr = csv.reader(f, delimiter='\t')
    naver_test = list(rdr)
    naver_test = [s[1] for s in naver_test[1:]]

pprint(naver_train[35:50])
# Out:
# ['패션에 대한 열정! 안나 윈투어!',
#  '키이라 나이틀리가 연기하고자 했던건 대체 정신장애일까 틱장애일까',
#  '허허...원작가 정신나간 유령이라... 재미있겠네요!',
#  '포스터는 있어보이는데 관객은 114명이네',
#  '이 영화가 왜 이렇게 저평가 받는지 모르겠다',
#  '단순하면서 은은한 매력의 영화',
#  "'다 알바생인가 내용도 없고 무서운거도 없고 웃긴거도 하나도 없음 완전 별싱거운 영화.ㅇ.ㅇ내ㅇ시간 넘 아까움 .. . 완전 낚임",
#  '오게두어라! 서리한이 굶주렸다!',
#  '정말 맘에 들어요. 그래서 또 보고싶은데 또 보는 방법이 없네? >.. ㅜㅡ',
#  '윤제문이라는 멋진 배우를 발견하게 됐어요. 소소한 일탈이 잔잔한 미소를 머금게 합니다. 음악은 조금 아쉽네요ㅠㅠ 8점 주고 싶은데 평점 '
#  '올리고 싶어 10점 줄게요^^',
#  '평점에속지마시길시간낭비 돈낭비임',
#  '리얼리티가 뛰어나긴 한데 큰 공감은 안간다. 이민기캐릭터는 정신의학상 분노조절장애 초기 증상일거다. 툭하면 사람패고 욕하고 물건 '
#  '파손하고.. 조금 오바였음. 극 초반엔 신선했는데 가면 갈수록 이민기 정신상태 공감불가.',
#  '마이너스는 왜없냐 ㅋ 뮤비 보고 영화수준 딱 알만하더군 ㅉㅉ 북한에서 이런거 만들라고 돈 대주던?',
#  '난 우리영화를 사랑합니다....^^;',
#  '데너리스 타르 가르엔...나도 용의주인이 되고 싶다...누이랑,근친상간이나 하고 다닐지라도,소설 속에선 제일 멋진 놈이 자이메 '
#  '라니스터였는데,드라마속에선,드래곤(용)이 제일 멋지네(웃음)감독님 토르-2 다크 월드는 말아 잡수셨을지라도,기본 선방은 했음']

# %%
# pos tagging, tokenizing
from konlpy.tag import Twitter
tagger = Twitter()

# *****pos tagging에 시간 좀 걸립니다******
def tokenize(doc):
    return ['/'.join(t) for t in tagger.pos(doc, norm=True, stem=True)]

sentences = [tokenize(d) for d in naver_train]

# %%
print('문장 총 개수: ', len(sentences))
for i in range(5):
    print(sentences[i])
# Out:
# 문장 총 개수:  150000
# ['아/Exclamation', '더빙/Noun', '../Punctuation', '진짜/Noun', '짜증/Noun', '나다/Verb', '목소리/Noun']
# ['흠/Noun', '.../Punctuation', '포스터/Noun', '보고/Noun', '초딩/Noun', '영화/Noun', '줄/Noun', '..../Punctuation', '오버/Noun', '연기/Noun', '조차/Josa', '가볍다/Adjective', '않다/Verb']
# ['너무/Noun', '재/Noun', '밓었/Noun', '다/Josa', '그래서/Adverb', '보다/Verb', '추천/Noun', '하다/Verb']
# ['교도소/Noun', '이야기/Noun', '구먼/Noun', '../Punctuation', '솔직하다/Adjective', '재미/Noun', '는/Josa', '없다/Adjective', '../Punctuation', '평점/Noun', '조정/Noun']
# ['사이몬페그/Noun', '의/Josa', '익살/Noun', '스런/Josa', '연기/Noun', '가/Josa', '돋보이다/Verb', '영화/Noun', '!/Punctuation', '스파이더맨/Noun', '에서/Josa', '늙다/Verb', '보이다/Verb', '하다/Verb', '크다/Verb', '스틴/Noun', '던스트/Noun', '가/Josa', '너무나/Noun', '도/Josa', '이쁘다/Adjective', '보이다/Verb']

# %%
from gensim import models
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# %%time
size=100
model = models.Word2Vec(size=size, window=7, min_count=1, workers=8,alpha=0.025, min_alpha=0.025)

model.build_vocab(sentences) # 오로지 한번만 스트럭팅 가능

# learning_rate를 낮춰가며 여러번 트레이닝
for epoch in range(15):
    if epoch%1 ==0:
        print('epoch:',epoch, 'train completed')
    model.train(sentences, total_examples=model.corpus_count, epochs=model.iter)
    model.alpha -= 0.002  # decrease the learning rate
    model.min_alpha = model.alpha  # fix the learning rate, no decay
# Out:
# epoch: 0 train completed
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   # Remove the CWD from sys.path while we load stuff.
# epoch: 1 train completed
# epoch: 2 train completed
# epoch: 3 train completed
# epoch: 4 train completed
# epoch: 5 train completed
# epoch: 6 train completed
# epoch: 7 train completed
# epoch: 8 train completed
# epoch: 9 train completed
# epoch: 10 train completed
# epoch: 11 train completed
# epoch: 12 train completed
# epoch: 13 train completed
# epoch: 14 train completed
# Wall time: 1min 6s

# %%
# model['재미/Noun'] # 이렇게 써도 된다 
model.wv.get_vector('재미/Noun')
# Out:
# array([ -8.37651789e-01,  -4.09695339e+00,  -6.72873110e-02,
#         -1.37403679e+00,  -2.71320343e+00,   4.68059921e+00,
#         -5.71496487e-01,   5.51190567e+00,  -1.79825020e+00,
#         -1.27291799e+00,   4.99172258e+00,  -2.44666740e-01,
#         -1.93593669e+00,  -3.50884175e+00,  -1.76506802e-01,
#         -2.15632468e-01,  -3.05503988e+00,  -6.82857186e-02,
#         -1.73245692e+00,   2.44168711e+00,  -3.14367509e+00,
#          3.96981835e-01,   6.84043467e-01,   1.73625422e+00,
#         -7.13991076e-02,  -4.55566406e+00,   3.44805479e-01,
#          2.62362170e+00,  -1.82470691e+00,   1.15604198e+00,
#          7.09960175e+00,   2.66416979e+00,  -1.79407615e-02,
#          1.82058990e+00,   2.73680711e+00,  -4.00320232e-01,
#         -6.60221756e-01,  -1.78898203e+00,   2.55182195e+00,
#          1.24575651e+00,  -2.93612242e+00,   6.25820923e+00,
#          1.33309400e+00,   2.74647564e-01,   2.80209929e-01,
#          2.36011410e+00,   6.81494921e-03,  -7.92679012e-01,
#          5.51715279e+00,  -1.95287144e+00,   4.23462223e-03,
#          4.10903883e+00,   1.74433851e+00,  -3.94931889e+00,
#          2.63123870e+00,   1.33780003e+00,   3.06783110e-01,
#          2.54144430e+00,  -1.25314963e+00,  -2.65511775e+00,
#          2.32284713e+00,   3.41259360e-01,   2.23484468e+00,
#         -2.35392523e+00,   2.55328274e+00,   2.96922612e+00,
#         -2.72355223e+00,   7.90672719e-01,  -1.26929092e+00,
#          1.23536634e+00,   2.33373547e+00,  -1.32668346e-01,
#         -5.05535698e+00,  -1.65541065e+00,   5.95387459e-01,
#         -3.96079350e+00,  -8.76621366e-01,   2.65778518e+00,
#         -1.09487247e+00,   2.47193313e+00,  -4.03011113e-01,
#         -2.48837209e+00,   3.15851307e+00,   3.55459595e+00,
#          1.10232794e+00,  -1.19486678e+00,  -3.18966103e+00,
#         -3.53417993e+00,   6.92082286e-01,   9.31864858e-01,
#         -2.88079166e+00,  -1.38668752e+00,  -6.69812560e-01,
#         -1.40794885e+00,  -1.81758940e+00,  -4.63430071e+00,
#          2.25466919e+00,  -2.95093775e+00,   3.67934406e-01,
#          2.65080976e+00], dtype=float32)

# %%
model.wv.vocab
# Out:
# {'아/Exclamation': <gensim.models.keyedvectors.Vocab at 0x29adcf54c88>,
#  '더빙/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f264cf8>,
#  '../Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f264d30>,
#  '진짜/Noun': <gensim.models.keyedvectors.Vocab at 0x29ae0c979b0>,
#  '짜증/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277940>,
#  '나다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f277978>,
#  '목소리/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2779b0>,
#  '흠/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2779e8>,
#  '.../Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f277a20>,
#  '포스터/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277a58>,
#  '보고/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277a90>,
#  '초딩/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277ac8>,
#  '영화/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277b00>,
#  '줄/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277b38>,
#  '..../Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f277b70>,
#  '오버/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277ba8>,
#  '연기/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277be0>,
#  '조차/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f277c18>,
#  '가볍다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f277c50>,
#  '않다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f277c88>,
#  '너무/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277cc0>,
#  '재/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277cf8>,
#  '밓었/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277d30>,
#  '다/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f277d68>,
#  '그래서/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f277da0>,
#  '보다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f277dd8>,
#  '추천/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277e10>,
#  '하다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f277e48>,
#  '교도소/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277e80>,
#  '이야기/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277eb8>,
#  '구먼/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277ef0>,
#  '솔직하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f277f28>,
#  '재미/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f277f60>,
#  '는/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f277f98>,
#  '없다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f277fd0>,
#  '평점/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281048>,
#  '조정/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281080>,
#  '사이몬페그/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2810b8>,
#  '의/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2810f0>,
#  '익살/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281128>,
#  '스런/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f281160>,
#  '가/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f281198>,
#  '돋보이다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2811d0>,
#  '!/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f281208>,
#  '스파이더맨/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281240>,
#  '에서/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f281278>,
#  '늙다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2812b0>,
#  '보이다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2812e8>,
#  '크다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f281320>,
#  '스틴/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281358>,
#  '던스트/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281390>,
#  '너무나/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2813c8>,
#  '도/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f281400>,
#  '이쁘다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f281438>,
#  '막/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281470>,
#  '걸음/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2814a8>,
#  '마/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2814e0>,
#  '떼다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f281518>,
#  '3/Number': <gensim.models.keyedvectors.Vocab at 0x29a8f281550>,
#  '세/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281588>,
#  '부터/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2815c0>,
#  '초등학교/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2815f8>,
#  '1/Number': <gensim.models.keyedvectors.Vocab at 0x29a8f281630>,
#  '학년/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281668>,
#  '생인/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2816a0>,
#  '8/Number': <gensim.models.keyedvectors.Vocab at 0x29a8f2816d8>,
#  '살다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f281710>,
#  './Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f281748>,
#  'ㅋㅋ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x29a8f281780>,
#  '별반/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2817b8>,
#  '개/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f2817f0>,
#  '아깝다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f281828>,
#  '움/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281860>,
#  '원작/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281898>,
#  '긴장감/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2818d0>,
#  '을/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f281908>,
#  '제대로/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281940>,
#  '살리다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f281978>,
#  '별/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2819b0>,
#  '반개/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2819e8>,
#  '욕/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281a20>,
#  '나오다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f281a58>,
#  '이응경/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281a90>,
#  '길용우/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281ac8>,
#  '생활/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281b00>,
#  '이/Determiner': <gensim.models.keyedvectors.Vocab at 0x29a8f281b38>,
#  '몇/NounPrefix': <gensim.models.keyedvectors.Vocab at 0x29a8f281b70>,
#  '년/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281ba8>,
#  '인지/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f281be0>,
#  '정말/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281c18>,
#  '발/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281c50>,
#  '로/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f281c88>,
#  '해도/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281cc0>,
#  '그것/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281cf8>,
#  '보단/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f281d30>,
#  '낫다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f281d68>,
#  '납치/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281da0>,
#  '감금/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281dd8>,
#  '만/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f281e10>,
#  '반복/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281e48>,
#  '드라마/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281e80>,
#  '가족/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281eb8>,
#  '못/VerbPrefix': <gensim.models.keyedvectors.Vocab at 0x29a8f281ef0>,
#  '사람/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281f28>,
#  '모엿/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281f60>,
#  '네/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f281f98>,
#  '액션/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f281fd0>,
#  '이/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f283048>,
#  '있다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f283080>,
#  '몇/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2830b8>,
#  '안/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2830f0>,
#  '되다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f283128>,
#  '왜/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283160>,
#  '이렇게/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f283198>,
#  '낮다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2831d0>,
#  '?/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f283208>,
#  '꽤/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283240>,
#  '볼/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283278>,
#  '한/Determiner': <gensim.models.keyedvectors.Vocab at 0x29a8f2832b0>,
#  '데/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2832e8>,
#  '헐리우드/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283320>,
#  '식/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f283358>,
#  '화려하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f283390>,
#  '길/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2833c8>,
#  '들이다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f283400>,
#  '걍/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f283438>,
#  '인피니트/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283470>,
#  '짱/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2834a8>,
#  '이다/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2834e0>,
#  '짱/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f283518>,
#  '♥/Foreign': <gensim.models.keyedvectors.Vocab at 0x29a8f283550>,
#  '볼때/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283588>,
#  '마다/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2835c0>,
#  '눈물/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2835f8>,
#  '나서다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f283630>,
#  '죽다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f283668>,
#  '90/Number': <gensim.models.keyedvectors.Vocab at 0x29a8f2836a0>,
#  '년대/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2836d8>,
#  '향수/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283710>,
#  '자극/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283748>,
#  '!!/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f283780>,
#  '허진호/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2837b8>,
#  '감성/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2837f0>,
#  '절제/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283828>,
#  '멜로/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283860>,
#  '달인/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283898>,
#  '~/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f2838d0>,
#  '울면/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283908>,
#  '서/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f283940>,
#  '손/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283978>,
#  '들/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f2839b0>,
#  '고/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2839e8>,
#  '횡단보도/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283a20>,
#  '건너다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f283a58>,
#  '때/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283a90>,
#  '뛰다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f283ac8>,
#  '치다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f283b00>,
#  '올/NounPrefix': <gensim.models.keyedvectors.Vocab at 0x29a8f283b38>,
#  '뻔/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283b70>,
#  '이범수/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283ba8>,
#  '드럽게못/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283be0>,
#  '해/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f283c18>,
#  '담/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283c50>,
#  '백/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f283c88>,
#  '하고/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f283cc0>,
#  '깔끔하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f283cf8>,
#  '좋다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f283d30>,
#  '신문/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283d68>,
#  '기사/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283da0>,
#  '로만/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283dd8>,
#  '자꾸/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283e10>,
#  '잊어버리다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f283e48>,
#  '그/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283e80>,
#  '이다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f283eb8>,
#  '것/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283ef0>,
#  '취향/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283f28>,
#  '은/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f283f60>,
#  '존중/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283f98>,
#  '내생/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f283fd0>,
#  '에/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f286048>,
#  '극장/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286080>,
#  '중/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f2860b8>,
#  '가장/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2860f0>,
#  '노잼/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286128>,
#  '노/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286160>,
#  '감동/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286198>,
#  '임/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2861d0>,
#  '스토리/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286208>,
#  '어거지/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286240>,
#  'ㄱ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x29a8f286278>,
#  '냥/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2862b0>,
#  '매번/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2862e8>,
#  '긴장/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286320>,
#  '재밌다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f286358>,
#  'ㅠㅠ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x29a8f286390>,
#  '차다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2863c8>,
#  '웃기다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f286400>,
#  '바스코/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286438>,
#  '이기/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286470>,
#  '면/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2864a8>,
#  '락스/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2864e0>,
#  '코/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286518>,
#  '라고/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f286550>,
#  '까다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f286588>,
#  '바비/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2865c0>,
#  '아이돌/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2865f8>,
#  '이라고/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f286630>,
#  '그냥/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286668>,
#  '안달/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2866a0>,
#  '난/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2866d8>,
#  '처럼/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f286710>,
#  '굿바이/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286748>,
#  '레닌/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286780>,
#  '표절/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2867b8>,
#  '인/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2867f0>,
#  '이해/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286828>,
#  '뒤/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286860>,
#  '갈수록/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286898>,
#  '없어지다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2868d0>,
#  '깨알/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286908>,
#  '캐스팅/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286940>,
#  '과/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f286978>,
#  '질퍽/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2869b0>,
#  '산/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2869e8>,
#  '뜻/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286a20>,
#  '내/Determiner': <gensim.models.keyedvectors.Vocab at 0x29a8f286a58>,
#  '용구성/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286a90>,
#  '자다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f286ac8>,
#  '버무러진/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286b00>,
#  '일드/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286b38>,
#  '약탈/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286b70>,
#  '자/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f286ba8>,
#  '를/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f286be0>,
#  '위/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286c18>,
#  '변명/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286c50>,
#  ',/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f286c88>,
#  '이르다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f286cc0>,
#  '저/Determiner': <gensim.models.keyedvectors.Vocab at 0x29a8f286cf8>,
#  '놈/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286d30>,
#  '착하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f286d68>,
#  '절대/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286da0>,
#  '아니다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f286dd8>,
#  '걸/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286e10>,
#  '요/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f286e48>,
#  '나름/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286e80>,
#  '심오/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286eb8>,
#  '한/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f286ef0>,
#  '듯/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286f28>,
#  '학생/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286f60>,
#  '선생/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f286f98>,
#  '놀다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f286fd0>,
#  '웃다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28a048>,
#  '건/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a080>,
#  '불가능하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28a0b8>,
#  '재미없다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28a0f0>,
#  '지루하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28a128>,
#  '같다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28a160>,
#  '음식/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a198>,
#  '인데/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f28a1d0>,
#  '도/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a208>,
#  '바베트/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a240>,
#  '만찬/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a278>,
#  '넘다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28a2b0>,
#  '차이/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a2e8>,
#  '남/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a320>,
#  ';/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f28a358>,
#  '볼게다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28a390>,
#  '별로/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a3c8>,
#  '안/VerbPrefix': <gensim.models.keyedvectors.Vocab at 0x29a8f28a400>,
#  '핀란드/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a438>,
#  '풍경/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a470>,
#  '이라도/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f28a4a8>,
#  '구경/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a4e0>,
#  '랫/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a518>,
#  'ㅡㅡ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x29a8f28a550>,
#  '평범하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28a588>,
#  '수작/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a5c0>,
#  '이라/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f28a5f8>,
#  '는걸/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a630>,
#  '말씀드리다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28a668>,
#  '주제/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a6a0>,
#  '중반/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a6d8>,
#  '다/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f28a710>,
#  '짤랐을꺼/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a748>,
#  '야/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f28a780>,
#  '납득/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a7b8>,
#  '수/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a7f0>,
#  '그렇다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28a828>,
#  '꼭/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a860>,
#  '끄다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28a898>,
#  'kl/Alpha': <gensim.models.keyedvectors.Vocab at 0x29a8f28a8d0>,
#  '2/Number': <gensim.models.keyedvectors.Vocab at 0x29a8f28a908>,
#  'g/Alpha': <gensim.models.keyedvectors.Vocab at 0x29a8f28a940>,
#  '고추/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28a978>,
#  '털다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28a9b0>,
#  '버리다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28a9e8>,
#  '카밀라/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28aa20>,
#  '벨/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28aa58>,
#  '발연기/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28aa90>,
#  '뎅/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28aac8>,
#  '센스/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28ab00>,
#  '연출/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28ab38>,
#  '력/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f28ab70>,
#  '탁월하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28aba8>,
#  '9/Number': <gensim.models.keyedvectors.Vocab at 0x29a8f28abe0>,
#  '점/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28ac18>,
#  '엄포/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28ac50>,
#  '스/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28ac88>,
#  '위력/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28acc0>,
#  '다시/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28acf8>,
#  '한번/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28ad30>,
#  '깨닫다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28ad68>,
#  '해주다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28ada0>,
#  '적/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28add8>,
#  '꽃/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28ae10>,
#  '검사/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28ae48>,
#  '님/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f28ae80>,
#  '완전/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28aeb8>,
#  '명품/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28aef0>,
#  '졸/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28af28>,
#  '쓰레기/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28af60>,
#  '진부/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28af98>,
#  '말/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28afd0>,
#  '도안/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c048>,
#  '돼다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28c080>,
#  '시간/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c0b8>,
#  '별점/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c0f0>,
#  '이리/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f28c128>,
#  '%/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f28c160>,
#  '라도/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f28c198>,
#  '기대하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28c1d0>,
#  '내/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c208>,
#  '죄인/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c240>,
#  '이다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28c278>,
#  '아직/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c2b0>,
#  '이/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c2e8>,
#  '인생/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c320>,
#  '최고/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c358>,
#  '패션/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c390>,
#  '대한/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c3c8>,
#  '열정/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c400>,
#  '안나/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c438>,
#  '윈/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c470>,
#  '투어/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c4a8>,
#  '키이라/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c4e0>,
#  '나이틀리/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c518>,
#  '대체/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c550>,
#  '정신장애/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c588>,
#  '틱장애/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c5c0>,
#  '허허/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f28c5f8>,
#  '정신/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c630>,
#  '나가다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28c668>,
#  '유령/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c6a0>,
#  '재미있다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28c6d8>,
#  '관객/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c710>,
#  '114/Number': <gensim.models.keyedvectors.Vocab at 0x29a8f28c748>,
#  '명/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c780>,
#  '이네/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f28c7b8>,
#  '평가/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c7f0>,
#  '받다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28c828>,
#  '모르다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28c860>,
#  '단순하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28c898>,
#  '은은하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28c8d0>,
#  '매력/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c908>,
#  "'/Punctuation": <gensim.models.keyedvectors.Vocab at 0x29a8f28c940>,
#  '알바생/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c978>,
#  '인가/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f28c9b0>,
#  '내용/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28c9e8>,
#  '무섭다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28ca20>,
#  '하나/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28ca58>,
#  '싱겁다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28ca90>,
#  'ㅇ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x29a8f28cac8>,
#  '낚임/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28cb00>,
#  '오다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28cb38>,
#  '두다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28cb70>,
#  '서리/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28cba8>,
#  '굶주렸/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28cbe0>,
#  '맘/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28cc18>,
#  '들다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f28cc50>,
#  '또/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28cc88>,
#  '방법/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28ccc0>,
#  '>../Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f28ccf8>,
#  'ㅜㅡ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x29a8f28cd30>,
#  '윤제문/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28cd68>,
#  '이라는/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f28cda0>,
#  '멋지다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28cdd8>,
#  '배우/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28ce10>,
#  '발견/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28ce48>,
#  '소소하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f28ce80>,
#  '일탈/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28ceb8>,
#  '잔잔/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28cef0>,
#  '미소/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28cf28>,
#  '먹음/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28cf60>,
#  '게/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f28cf98>,
#  '음악/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f28cfd0>,
#  '조금/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290048>,
#  '아쉽다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f290080>,
#  '주다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2900b8>,
#  '싶다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2900f0>,
#  '올리다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f290128>,
#  '10/Number': <gensim.models.keyedvectors.Vocab at 0x29a8f290160>,
#  '^^/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f290198>,
#  '속지/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2901d0>,
#  '말다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f290208>,
#  '낭비/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290240>,
#  '돈/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290278>,
#  '리얼리티/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2902b0>,
#  '뛰어나다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2902e8>,
#  '공감/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290320>,
#  '간다/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290358>,
#  '이민기/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290390>,
#  '캐릭터/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2903c8>,
#  '정신의학/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290400>,
#  '상/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f290438>,
#  '분노조절/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290470>,
#  '장애/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2904a8>,
#  '초기/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2904e0>,
#  '증상/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290518>,
#  '툭하면/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290550>,
#  '패/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290588>,
#  '물건/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2905c0>,
#  '파손/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2905f8>,
#  '오바/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290630>,
#  '극/NounPrefix': <gensim.models.keyedvectors.Vocab at 0x29a8f290668>,
#  '초반/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2906a0>,
#  '엔/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2906d8>,
#  '신선하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f290710>,
#  '가면/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290748>,
#  '상태/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290780>,
#  '불가/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2907b8>,
#  '마이너스/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2907f0>,
#  'ㅋ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x29a8f290828>,
#  '뮤비/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290860>,
#  '수준/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290898>,
#  '딱/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f2908d0>,
#  '알/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290908>,
#  'ㅉㅉ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x29a8f290940>,
#  '북한/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290978>,
#  '이렇다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2909b0>,
#  '만들다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2909e8>,
#  '대다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f290a20>,
#  '난/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290a58>,
#  '우리/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290a90>,
#  '사랑/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290ac8>,
#  '....^^;/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f290b00>,
#  '데너/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290b38>,
#  '리스/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290b70>,
#  '타르/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290ba8>,
#  '가르다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f290be0>,
#  '용의/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290c18>,
#  '주인/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290c50>,
#  '누/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290c88>,
#  '이랑/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f290cc0>,
#  '근친상간/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290cf8>,
#  '이나/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f290d30>,
#  '다니다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f290d68>,
#  '소설/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290da0>,
#  '속/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290dd8>,
#  '에선/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f290e10>,
#  '제일/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290e48>,
#  '자/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290e80>,
#  '메/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290eb8>,
#  '라/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f290ef0>,
#  '니스/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290f28>,
#  '터/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290f60>,
#  '드래곤/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f290f98>,
#  '(/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f290fd0>,
#  '용/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294048>,
#  ')/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f294080>,
#  '웃음/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2940b8>,
#  '감독/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2940f0>,
#  '토르/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294128>,
#  '-/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f294160>,
#  '다크/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294198>,
#  '월드/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2941d0>,
#  '아/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f294208>,
#  '잡수다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f294240>,
#  '기본/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294278>,
#  '선방/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2942b0>,
#  '영혼/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2942e8>,
#  '어루만져/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294320>,
#  '수도/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294358>,
#  '거치다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f294390>,
#  '상사/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2943c8>,
#  '잠시/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294400>,
#  '잊다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f294438>,
#  '동화/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294470>,
#  '행복하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2944a8>,
#  '야/Exclamation': <gensim.models.keyedvectors.Vocab at 0x29a8f2944e0>,
#  '세르게이/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294518>,
#  '작다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f294550>,
#  '맵다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f294588>,
#  '맛/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2945c0>,
#  '포퐁/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2945f8>,
#  '저그/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294630>,
#  '콩/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294668>,
#  '진호/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2946a0>,
#  '가슴/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2946d8>,
#  '시리/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294710>,
#  '자체/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294748>,
#  '난또/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294780>,
#  '저/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2947b8>,
#  '꼬마/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2947f0>,
#  '애가/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294828>,
#  '무슨/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294860>,
#  '원한/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294898>,
#  '깊다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2948d0>,
#  '.,./Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f294908>,
#  'OO/Alpha': <gensim.models.keyedvectors.Vocab at 0x29a8f294940>,
#  '혼자/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294978>,
#  '나대다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2949b0>,
#  '어쩌라고/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f2949e8>,
#  '전/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294a20>,
#  '충격/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294a58>,
#  '적다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f294a90>,
#  '기분/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294ac8>,
#  '완전하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f294b00>,
#  '푹/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294b38>,
#  '꺼지다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f294b70>,
#  '느낌/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294ba8>,
#  '활/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294be0>,
#  '이라고는/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f294c18>,
#  '무겁다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f294c50>,
#  '지독/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294c88>,
#  '차갑다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f294cc0>,
#  '무자비/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294cf8>,
#  '그저/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f294d30>,
#  '일본인/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294d68>,
#  '상상력/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294da0>,
#  '대단하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f294dd8>,
#  '생각/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294e10>,
#  '심심하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f294e48>,
#  '백봉기/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294e80>,
#  '언제/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294eb8>,
#  '그대로/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294ef0>,
#  '맞다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f294f28>,
#  '예측/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294f60>,
#  '카리스마/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294f98>,
#  '악역/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f294fd0>,
#  '불알/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298048>,
#  '당황/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298080>,
#  '아무튼/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f2980b8>,
#  '중간/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2980f0>,
#  '끝나다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f298128>,
#  '녹다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f298160>,
#  '일상/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298198>,
#  '밋밋한/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2981d0>,
#  '계속/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298208>,
#  '전개도/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298240>,
#  '느리다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f298278>,
#  '주인공/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2982b0>,
#  '은희/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2982e8>,
#  '두컷/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298320>,
#  '소극/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298358>,
#  '적/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f298390>,
#  '모습/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2983c8>,
#  'ㅜㅜ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x29a8f298400>,
#  '맨날/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f298438>,
#  '기대/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298470>,
#  '전개/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2984a8>,
#  '좀/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2984e0>,
#  '빨리/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f298518>,
#  '가슴속/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298550>,
#  '온/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298588>,
#  '감정/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2985c0>,
#  '헤집다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2985f8>,
#  '예요/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f298630>,
#  '많다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f298668>,
#  '다큐/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2986a0>,
#  '우리나라/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2986d8>,
#  '슬프다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f298710>,
#  '현대/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298748>,
#  '사의/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298780>,
#  '단면/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2987b8>,
#  '대해/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2987f0>,
#  '깊이/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298828>,
#  '사죄/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298860>,
#  '바로/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298898>,
#  '잡기/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2988d0>,
#  '위해/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298908>,
#  '노력/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298940>,
#  '말로/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298978>,
#  '듣다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2989b0>,
#  '보도/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2989e8>,
#  '연맹/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298a20>,
#  '민간인/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298a58>,
#  '학살/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298a90>,
#  '이정/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298ac8>,
#  '일/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298b00>,
#  '이야/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f298b38>,
#  '명백/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298b70>,
#  '살인/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298ba8>,
#  '살인자/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298be0>,
#  '어디/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298c18>,
#  '예전/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298c50>,
#  '작품/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298c88>,
#  '에피소드/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298cc0>,
#  '재탕/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298cf8>,
#  '삼탕/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298d30>,
#  '사골/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298d68>,
#  '우려/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298da0>,
#  '먹듯/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298dd8>,
#  '으로/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f298e10>,
#  '가다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f298e48>,
#  '시청률/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298e80>,
#  '아예/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298eb8>,
#  '이제/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298ef0>,
#  '70/Number': <gensim.models.keyedvectors.Vocab at 0x29a8f298f28>,
#  '회/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298f60>,
#  '120/Number': <gensim.models.keyedvectors.Vocab at 0x29a8f298f98>,
#  '부작/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f298fd0>,
#  '이라니/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f29b048>,
#  '김남길/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b080>,
#  '백점/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b0b8>,
#  '짜다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f29b0f0>,
#  '연기력/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b128>,
#  '몰입도/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b160>,
#  '에도/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f29b198>,
#  '불구/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b1d0>,
#  '손예진/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b208>,
#  'ㅈㅈ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x29a8f29b240>,
#  '비슷하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f29b278>,
#  '분/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b2b0>,
#  '한테/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f29b2e8>,
#  '늘다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f29b320>,
#  '노래실력/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b358>,
#  '뽑다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f29b390>,
#  '박시환/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b3c8>,
#  'mama/Alpha': <gensim.models.keyedvectors.Vocab at 0x29a8f29b400>,
#  '망신/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b438>,
#  '일본/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b470>,
#  '??/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f29b4a8>,
#  '유치/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b4e0>,
#  '이틀/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b518>,
#  '만에/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f29b550>,
#  '근데/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f29b588>,
#  '차/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b5c0>,
#  '넣다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f29b5f8>,
#  '조작/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b630>,
#  '안이/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b668>,
#  '열리다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f29b6a0>,
#  '집/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b6d8>,
#  '활짝/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b710>,
#  '무/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b748>,
#  '나/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f29b780>,
#  '들어가다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f29b7b8>,
#  '문자/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b7f0>,
#  '비번/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b828>,
#  '걸리다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f29b860>,
#  '억지/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b898>,
#  '스럽다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f29b8d0>,
#  '그래도/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f29b908>,
#  '졸작/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b940>,
#  '달팽이/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b978>,
#  '빨/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29b9b0>,
#  '라서/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f29b9e8>,
#  '더/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29ba20>,
#  '어설픈/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29ba58>,
#  '어이/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29ba90>,
#  '결말/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bac8>,
#  '부패/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bb00>,
#  '로마노프/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bb38>,
#  '왕조/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bb70>,
#  '기리/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bba8>,
#  '뭣같/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bbe0>,
#  '온몸/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bc18>,
#  '항거/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bc50>,
#  '러시아/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bc88>,
#  '민중/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bcc0>,
#  '폭도/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bcf8>,
#  '냐/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f29bd30>,
#  '무난/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bd68>,
#  '펴다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f29bda0>,
#  '매우/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bdd8>,
#  '실망/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29be10>,
#  '...../Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f29be48>,
#  '한국영/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29be80>,
#  '화/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f29beb8>,
#  '흥행/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bef0>,
#  '코드/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bf28>,
#  ':/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f29bf60>,
#  '갈등/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bf98>,
#  '계/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29bfd0>,
#  '화해/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e048>,
#  '남발/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e080>,
#  '뻔하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f29e0b8>,
#  '뭐/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e0f0>,
#  '아햏햏/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e128>,
#  '시작/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e160>,
#  '분만/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e198>,
#  '리플릿/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e1d0>,
#  '사진/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e208>,
#  '불안하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f29e240>,
#  '단연/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e278>,
#  '럼/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e2b0>,
#  '먹다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f29e2e8>,
#  '에게/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f29e320>,
#  '뭘/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e358>,
#  '엉망/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e390>,
#  '진창/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e3c8>,
#  '개/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e400>,
#  '우뢰매/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e438>,
#  ';;;/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f29e470>,
#  '진정/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e4a8>,
#  '위대하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f29e4e0>,
#  '별루/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e518>,
#  '내일/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e550>,
#  '`/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f29e588>,
#  '조미/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e5c0>,
#  '막문위/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e5f8>,
#  '좋아하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f29e630>,
#  '가요/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e668>,
#  '골/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e6a0>,
#  '눈/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e6d8>,
#  '부라/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e710>,
#  '릴때/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e748>,
#  '쓰러지다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f29e780>,
#  '성룡/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e7b8>,
#  '최악/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e7f0>,
#  '때리다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f29e828>,
#  '걸스데이/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e860>,
#  '이혜리/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e898>,
#  '서기/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e8d0>,
#  '백인/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e908>,
#  '공주/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f29e940>,
#  '귀엽다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f29e978>,
# ...
#  '광고/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3128>,
#  '어떻다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3160>,
#  '킬링타임/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3198>,
#  '크리스마스/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a31d0>,
#  '떠오르다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3208>,
#  '행복/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3240>,
#  '요/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3278>,
#  "'-'/Punctuation": <gensim.models.keyedvectors.Vocab at 0x29a8f2a32b0>,
#  'ㅎㅎ/KoreanParticle': <gensim.models.keyedvectors.Vocab at 0x29a8f2a32e8>,
#  '빠지다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3320>,
#  '쫌/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3358>,
#  '산만/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3390>,
#  ';;/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f2a33c8>,
#  '태어나다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3400>,
#  '처음/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3438>,
#  ',,,,/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3470>,
#  '불륜/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a34a8>,
#  '로맨스/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a34e0>,
#  ',,/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3518>,
#  '왕/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3550>,
#  '아주/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3588>,
#  '짬뽕/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a35c0>,
#  '믹스/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a35f8>,
#  '음향/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3630>,
#  '하아/Exclamation': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3668>,
#  '별루더/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a36a0>,
#  '기준/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a36d8>,
#  '패널/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3710>,
#  '가구/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3748>,
#  '머/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3780>,
#  '명작/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a37b8>,
#  '망치/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a37f0>,
#  '서다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3828>,
#  '이상하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3860>,
#  '몬스터/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3898>,
#  '주식회사/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a38d0>,
#  'D/Alpha': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3908>,
#  '......../Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3940>,
#  '소재/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3978>,
#  '흥미/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a39b0>,
#  '끌/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a39e8>,
#  '지만/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3a20>,
#  '투/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3a58>,
#  '박해/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3a90>,
#  '몰입/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3ac8>,
#  '보지/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3b00>,
#  '마르다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3b38>,
#  '중국인/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3b70>,
#  '특유/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3ba8>,
#  '과장/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3be0>,
#  '허풍/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3c18>,
#  '안간힘/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3c50>,
#  '쓸다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3c88>,
#  '가상/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3cc0>,
#  '고증/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3cf8>,
#  '현실/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3d30>,
#  '감/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3d68>,
#  '떨어지다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3da0>,
#  '거북/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3dd8>,
#  '도대체/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3e10>,
#  '까지/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3e48>,
#  '스스로/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3e80>,
#  '과대/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3eb8>,
#  '포장/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3ef0>,
#  '불법체류자/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3f28>,
#  '잡다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3f60>,
#  '우상화/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3f98>,
#  '미국/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a3fd0>,
#  '따뜻하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5048>,
#  '뭐임/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5080>,
#  '삶속/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a50b8>,
#  '생애/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a50f0>,
#  '전부/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5128>,
#  '드러나다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5160>,
#  '보/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5198>,
#  '지난/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a51d0>,
#  '후/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5208>,
#  '남다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5240>,
#  '대/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5278>,
#  '...;;;/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f2a52b0>,
#  '지나/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a52e8>,
#  '봐/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5320>,
#  '순수하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5358>,
#  '숀펜/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5390>,
#  '또한/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a53c8>,
#  '甲/Foreign': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5400>,
#  '올레/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5438>,
#  '공짜/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5470>,
#  '허다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a54a8>,
#  '문제/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a54e0>,
#  '연기자/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5518>,
#  '전혀/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5550>,
#  '배역/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5588>,
#  '어울리다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a55c0>,
#  '그리고/Conjunction': <gensim.models.keyedvectors.Vocab at 0x29a8f2a55f8>,
#  '상대/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5630>,
#  '따로/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5668>,
#  '놓다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a56a0>,
#  '~~/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f2a56d8>,
#  '보아/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5710>,
#  '라미란/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5748>,
#  '아들/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5780>,
#  '젤/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a57b8>,
#  '욕심/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a57f0>,
#  '어느/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5828>,
#  '쪽/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5860>,
#  '만이라도/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5898>,
#  '....../Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f2a58d0>,
#  '빵점/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5908>,
#  '베댓/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5940>,
#  '잘/VerbPrefix': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5978>,
#  '모자라다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a59b0>,
#  '도둑/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a59e8>,
#  '뫼비우스/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5a20>,
#  '나라/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5a58>,
#  '만들어지다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5a90>,
#  '믿어지다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5ac8>,
#  '..?/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5b00>,
#  '찌릿/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5b38>,
#  '짜릿/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5b70>,
#  '나/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5ba8>,
#  '두/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5be0>,
#  '용기/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5c18>,
#  '교훈/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5c50>,
#  '당시/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5c88>,
#  '상황/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5cc0>,
#  '주입/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5cf8>,
#  '식이/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5d30>,
#  '케이블/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5d68>,
#  '그만/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5da0>,
#  '다르덴/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5dd8>,
#  '차이밍량/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5e10>,
#  '섞이다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5e48>,
#  '채/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5e80>,
#  '그릇/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5eb8>,
#  '담기다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5ef0>,
#  '여군/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5f28>,
#  '잼/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5f60>,
#  '건지다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5f98>,
#  '엠비씨/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a5fd0>,
#  '질/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9048>,
#  '린다/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9080>,
#  '한석규/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a90b8>,
#  '김혜수/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a90f0>,
#  '많이/Adverb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9128>,
#  '에볼라/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9160>,
#  '바이러스/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9198>,
#  '떠들다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a91d0>,
#  '석/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9208>,
#  '해서/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9240>,
#  '성/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9278>,
#  '20/Number': <gensim.models.keyedvectors.Vocab at 0x29a8f2a92b0>,
#  '여년전/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a92e8>,
#  '보기/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9320>,
#  '믿다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9358>,
#  '힘들다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9390>,
#  '정도/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a93c8>,
#  '고본/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9400>,
#  '마지막/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9438>,
#  '후반/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9470>,
#  '부가/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a94a8>,
#  '살짝/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a94e0>,
#  '하지만/Conjunction': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9518>,
#  '떨다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9550>,
#  '용가리/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9588>,
#  '짱짱맨/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a95c0>,
#  '감히/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a95f8>,
#  '하나로/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9630>,
#  '꼽/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9668>,
#  '살/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a96a0>,
#  '야하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a96d8>,
#  '나르다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9710>,
#  '고민/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9748>,
#  '모건/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9780>,
#  '프리/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a97b8>,
#  '멀다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a97f0>,
#  '나이/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9828>,
#  '여전하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9860>,
#  '섹시하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9898>,
#  '작가/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a98d0>,
#  '용이/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9908>,
#  '재방송/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9940>,
#  '혹/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9978>,
#  '시나/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a99b0>,
#  '답/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a99e8>,
#  '여운/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9a20>,
#  '웬만하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9a58>,
#  '상업/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9a90>,
#  '지/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9ac8>,
#  '퀄리티/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9b00>,
#  '쩔다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9b38>,
#  '충분하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9b70>,
#  '개인/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9ba8>,
#  '잔인/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9be0>,
#  '노출씬/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9c18>,
#  '화끈/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9c50>,
#  '국산/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9c88>,
#  '아끼다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9cc0>,
#  '보임/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9cf8>,
#  '끝내/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9d30>,
#  '지겹다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9d68>,
#  '역시/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9da0>,
#  '드니/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9dd8>,
#  '의/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9e10>,
#  '일품/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9e48>,
#  '맥스/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9e80>,
#  '샘/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9eb8>,
#  '죽이다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9ef0>,
#  '바랬/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9f28>,
#  '괜찮다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9f60>,
#  '지네/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9f98>,
#  '뜨다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2a9fd0>,
#  '찍을껀데/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad048>,
#  '???/Punctuation': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad080>,
#  '면상/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad0b8>,
#  '알다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad0f0>,
#  '자신/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad128>,
#  '어린이/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad160>,
#  '내/VerbPrefix': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad198>,
#  '어리다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad1d0>,
#  '동심/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad208>,
#  '멀리/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad240>,
#  '무술/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad278>,
#  '인/Suffix': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad2b0>,
#  '총을드/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad2e8>,
#  '크리스토퍼/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad320>,
#  '왈츠/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad358>,
#  '타란티노/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad390>,
#  '조합/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad3c8>,
#  '이란/Josa': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad400>,
#  '한국/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad438>,
#  '유명/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad470>,
#  '한편/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad4a8>,
#  '외국/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad4e0>,
#  '상상/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad518>,
#  '초월/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad550>,
#  '유명하다/Adjective': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad588>,
#  '오랜만/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad5c0>,
#  '종방/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad5f8>,
#  '되어다/Verb': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad630>,
#  '오늘/Noun': <gensim.models.keyedvectors.Vocab at 0x29a8f2ad668>,
#  ...}

# %%
model.most_similar('은/Josa')
# Out:
# [('이/Josa', 0.8837136626243591),
#  ('도/Josa', 0.778893232345581),
#  ('을/Josa', 0.7567287683486938),
#  ('.../Punctuation', 0.746350884437561),
#  ('./Punctuation', 0.7432119846343994),
#  (',/Punctuation', 0.7419814467430115),
#  ('../Punctuation', 0.7400909066200256),
#  ('보다/Verb', 0.6947461366653442),
#  ('하다/Verb', 0.6912280321121216),
#  ('..../Punctuation', 0.6882936954498291)]

# %%
model.wv.most_similar(positive=['엄마/Noun', '남자/Noun'], negative=['여자/Noun'])
# Out:
# [('아빠/Noun', 0.7501145005226135),
#  ('아버지/Noun', 0.7234706282615662),
#  ('어머니/Noun', 0.6668721437454224),
#  ('친구/Noun', 0.6297358274459839),
#  ('할아버지/Noun', 0.6252042651176453),
#  ('동생/Noun', 0.5920482873916626),
#  ('강아지/Noun', 0.5888135433197021),
#  ('누나/Noun', 0.5816317796707153),
#  ('딸/Noun', 0.5810499787330627),
#  ('부모/Noun', 0.5616966485977173)]

# %%
model.similarity('한국/Noun', '미국/Noun')
# Out:
# 0.68810290921476391
