# %% [markdown]
# ---
# ## Song genre prediction
# > - 노래 가사를 이용해서 장르를 예측하는 모델.
# - 16800곡의 노래를 {'Country', 'Electronic', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Rock'} 7장르에 대해 예측.
# - nltk, word2vec을 이용해 노래의 200단어만 특수문자 제외하고 tokenizing 후 embedding

# %%
import time
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, KFold

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

import tensorflow as tf
from pprint import pprint
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import nltk
from gensim import models, similarities
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ---
# ## 메모리 부족때문에 전처리와 학습 과정 분리
# > 전처리후 저장해둔 csv, w2v model로드

# %%
# 전처리한 데이터 로드
df2 = pd.read_csv('lyrics_refine.csv')
# 저장한 w2v 모델 로드
model = models.word2vec.Word2Vec.load('models/word2vec.model')

# %%
# 전처리된 데이터 예시
df2.head()
# Out:
#   genre                                                tok
# 0   Pop  oh baby how you doing you know i m gonna cut r...
# 1   Pop  playin everything so easy it s like you seem s...
# 2   Pop  oh oh oh i oh oh oh i verse if i wrote a book ...
# 3   Pop  party the people the people the party it s pop...
# 4   Pop  this is just another day that i would spend wa...

# %%
# 원본 데이터 비율 유지한 테스트셋 만들기
empty = [0]*len(df2)
df2, df2_for_test, no, no_ = train_test_split(df2, empty, test_size=0.1, random_state=3)

# %%
# train/test set 비율 확인
order = df2['genre'].value_counts().index
plt.subplots(figsize=(15,5))
plt.subplot(121)
plt.title('Training set')
plt.xticks(rotation=45)
sns.countplot(x=df2['genre'], order = order)
plt.subplot(122)
plt.title('Test set')
plt.xticks(rotation=45)
sns.countplot(x=df2_for_test['genre'], order = order)
print(set(df2['genre']))

# df2_for_test['genre'].value_counts().plot(kind='bar')
# Out:
# {'Pop', 'Rock', 'Country', 'Other', 'R&B', 'Not Available', 'Hip-Hop', 'Folk', 'Jazz', 'Metal', 'Electronic', 'Indie'}

# %%
# 레이블 최소, 최대 개수 확인
print(len(df2[df2['genre'] ==  'Jazz']), len(df2[df2['genre'] ==  'Rock']), 
      len(df2_for_test[df2_for_test['genre'] ==  'Jazz']), len(df2_for_test[df2_for_test['genre'] ==  'Rock']))
# Out:
# 2421 43240 284 4785

# %%
# tain set 포본 추출
min = 2400
d1 = df2[df2['genre'] == 'Country'][:min]
d2 = df2[df2['genre'] == 'Electronic'][:min]
# d3 = df2[df2['genre'] ==  'Folk']
d4 = df2[df2['genre'] == 'Hip-Hop'][:min]
# d5 = df2[df2['genre'] ==  'Indie']
d6 = df2[df2['genre'] ==  'Jazz'][:min]
d7 = df2[df2['genre'] ==  'Metal'][:min]
# d8 = df2[df2['genre'] ==  'Not Available']
# d9 = df2[df2['genre'] ==  'Other']
d10 = df2[df2['genre'] ==  'Pop'][:min]
# d11 = df2[df2['genre'] ==  'R&B']
d12 = df2[df2['genre'] ==  'Rock'][:min]

# %%
# test set 포본 추출
min_ = 280
d1_ = df2_for_test[df2_for_test['genre'] == 'Country'][:min_]
d2_ = df2_for_test[df2_for_test['genre'] == 'Electronic'][:min_]
# d3_ = df2_for_test[df2_for_test['genre'] ==  'Folk']
d4_ = df2_for_test[df2_for_test['genre'] == 'Hip-Hop'][:min_]
# d5_ = df2_for_test[df2_for_test['genre'] ==  'Indie']
d6_ = df2_for_test[df2_for_test['genre'] ==  'Jazz'][:min_]
d7_ = df2_for_test[df2_for_test['genre'] ==  'Metal'][:min_]
# d8_ = df2_for_test[df2_for_test['genre'] ==  'Not Available']
# d9_ = df2_for_test[df2_for_test['genre'] ==  'Other']
d10_ = df2_for_test[df2_for_test['genre'] ==  'Pop'][:min_]
# d11_ = df2_for_test[df2_for_test['genre'] ==  'R&B']
d12_ = df2_for_test[df2_for_test['genre'] ==  'Rock'][:min_]

# %%
# 양 적은거 제거 5,3,11,9
df2 = pd.concat([d1,d2,d4,d6,d7,d10,d12], axis=0)
df2_for_test = pd.concat([d1_,d2_,d4_,d6_,d7_,d10_,d12_], axis=0)

# %%
print(len(df2), len(df2_for_test))
# df2.head()
# Out:
# 16800 1960

# %%
set(df2['genre'])
# Out:
# {'Country', 'Electronic', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Rock'}

# %%
# w2v vector dictionary에 없는 단어 임베딩 위해서 mean값 게산해서 대신 넣음
voc = list(model.wv.vocab)
all_w2v = [model[i] for i in voc]
all_w2v = np.array(all_w2v)

mean = all_w2v.mean(axis=0)
mean.shape
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# (200,)

# %%
# 앞 200단어만 추림
vec = []
for i in df2['tok']:
    arr = i.split(' ')
    temp=[]
    for j in arr[:200]:
        temp.append(j)
    vec.append(temp)

vec_for_test = []
for i in df2_for_test['tok']:
    arr = i.split(' ')
    temp=[]
    for j in arr[:200]:
        temp.append(j)
    vec_for_test.append(temp)

# %% [markdown]
# ---
# ## 여기부터 CNN 학습 과정

# %% [markdown]
# > 메모리 절약용 제너레이터
# 실시간으로 워드 임베딩해서 이전 변수에 덮어씀

# %%
# 실제로 사용할 데이터
print('노래 총 개수:', len(vec), len(df2['genre']))
# Out:
# 노래 총 개수: 16800 16800

# %%
# 각 단어들에 word embedding #row*40000
def tok_embedding(tok_vec):
    w2v_vec = []
    for i in tok_vec: # 그냥 vec넣으면 134170 다들어감 메모리 절대 부족!!! 파이프라인 구축 필요
        temp =[]
        for j in i:
            try:
                temp += list(model[j])
            except:
                temp += list(mean)
        w2v_vec.append(temp)
#     reshape은 텐서플로에서 함
#     w2v_vec = np.array(w2v_vec, dtype='float16')
#     return w2v_vec.reshape([-1,200,embed_dim])
    return w2v_vec

# %%
# 피처 데이터, 레이블, 미니배치 갯수
def getMiniBatch(df_, y, n):
    if len(df_) != len(y):
        print('Feature and label num is not equal.')
        return
    start = 0
    while True:
        if start>= len(df_):
#             셔플을 안하니까 좀 되네... -> df, y 묶어서 셔플해야 함
#             df_ = df_.sample(frac=1).reset_index(drop=True) # 1epoch 이후 셔플
            start = 0
        embeded_df = tok_embedding(df_[start: start+n])
        yield embeded_df, y[start: start+n]
#         yield df_[start: start+n], y[start: start+n]   
        start += n

# %%
# 피처 데이터, 레이블, 미니배치 갯수, random sampling
import random
def getMiniBatch2(x, y, n):
    if len(x) != len(y):
        print('Feature and label num is not equal.')
        return
    rand_idx = random.sample(list(range(len(x))), n)
    x_ = [x[i] for i in rand_idx]
    y_ = [y[i] for i in rand_idx]
    return tok_embedding(x_), y_

# %%
# 잘 되는지 확인
batch = getMiniBatch(vec, df2['genre'], 200)
a,b = next(batch)
a[0]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#  0.5456405,
#  -1.844365,
#  0.69842404,
#  0.33345848,
#  1.5912845,
#  0.7168019,
#  -2.068006,
#  5.0861044,
#  -0.99256057,
#  -3.4996731,
#  -0.22897306,
#  ...]

# %% [markdown]
# ---
# ## lable 전처리

# %%
# genre: 카테고리 -> 숫자로 변경
# genre = {'Electronic':0, 'Jazz':1, 'Metal':2, 'Not Available':3, 'Other':4,
#          'Country':5, 'R&B':6, 'Pop':7, 'Rock':8, 'Indie':9, 'Folk':10, 'Hip-Hop':11}
genre = {'Electronic':0, 'Jazz':1, 'Metal':2, 
         'Country':3, 'Pop':4, 'Rock':5, 'Hip-Hop':6}
label = [genre[i] for i in df2['genre']]
label_for_test = [genre[i] for i in df2_for_test['genre']]

# %%
X_all = vec
Y_all = label

# %%
# 실험용 데이터 1/10로 줄이는 부분
# X2, _, Y2, __ = train_test_split(X, Y, test_size=1, random_state=3)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_all, Y_all, test_size=0.02, random_state=3)

# %%
# data label 분포확인 
order = list(range(len(set(Y_all))))
plt.subplots(figsize=(18,5))
plt.subplot(141)
plt.title('Test+Val set:%d'%len(Y_all))
sns.countplot(x=Y_all, order = order)
plt.subplot(142)
plt.title('Train set:%d'%len(X_train))
sns.countplot(x=Y_train, order = order)
plt.subplot(143)
plt.title('Validation set:%d'%len(X_val))
sns.countplot(x=Y_val, order = order)
plt.subplot(144)
plt.title('Test set:%d'%len(label_for_test))
sns.countplot(x=label_for_test, order = order)
print(set(Y_all))
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %%
sess = tf.InteractiveSession()
Y_train = sess.run(tf.one_hot(Y_train, len(set(Y_all))))
Y_val = sess.run(tf.one_hot(Y_val, len(set(Y_all))))
label_for_test_onehot = sess.run(tf.one_hot(label_for_test, len(set(Y_all))))
print([len(X_train),len(X_train[0])], [len(Y_train),len(Y_train[0])], [len(X_val),len(X_val[0])], [len(Y_val),len(Y_val[0])], len(label_for_test_onehot))
# Out:
# [16464, 200] [16464, 7] [336, 200] [336, 7] 1960

# %% [markdown]
# ### Bi-LSTM 그래프 만들기

# %%
tf.reset_default_graph()
# train Parameters
seq_length = 200
data_dim = 200
hidden_dim = 100
output_dim = 7
learning_rate = 0.001
epoch = 7
batch_size = 100

# input place holders
X = tf.placeholder(tf.float32, [None, seq_length*data_dim])
X_re = tf.reshape(X, [-1, seq_length, data_dim])
Y = tf.placeholder(tf.float32, [None, output_dim])

# build a Bi-directional LSTM network
lstm_fw_cell = tf.contrib.rnn.BasicLSTMCell(num_units=hidden_dim, forget_bias=1.0)
lstm_bw_cell = tf.contrib.rnn.BasicLSTMCell(num_units=hidden_dim, forget_bias=1.0)
X_seq = tf.unstack(X_re, seq_length, 1)
outputs, _, _ = tf.contrib.rnn.static_bidirectional_rnn(lstm_fw_cell, lstm_bw_cell,
                                                        X_seq, dtype=tf.float32)
fc1 = tf.contrib.layers.fully_connected(outputs[-1], 100, activation_fn=tf.nn.relu)  # We use the last cell's output

'''2-layer LSTM 
# cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(num_units=hidden_dim, state_is_tuple=True)
#                                     for _ in range(2)], state_is_tuple=True) # multiple layers
# outputs, _states = tf.nn.dynamic_rnn(cell, X_re, dtype=tf.float32)
# fc1 = tf.contrib.layers.fully_connected(outputs[:, -1], 100, activation_fn=tf.nn.relu)  # We use the last cell's output
'''
Y_pred = tf.contrib.layers.fully_connected(fc1, output_dim, activation_fn=None)  # We use the last cell's output
hypothesis = tf.nn.softmax(Y_pred)

# cost/loss
cost = tf.reduce_mean(-tf.reduce_sum(Y*tf.log(hypothesis), axis=1))

# optimizer
optimizer = tf.train.AdamOptimizer(learning_rate)
train_step = optimizer.minimize(cost)

# prediction
predicted = tf.argmax(hypothesis, 1)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, tf.argmax(Y, 1)), dtype=tf.float32))

total_iter = epoch*int(len(X_train)/batch_size) # 총 학습횟수
print('total iteration:', total_iter, '...')
# Out:
# total iteration: 1148 ...

# %%
# accuracy_, cost_ 계산하는 함수
# prop 전체 테스트셋에서 몇 %나 사용할지
def calc_acc_cost(x, y, prop):
    accuracy_ = 0
    cost_ = 0
    batch_size = int(len(y)*prop)
    # 계속 같은 데이터 부분만 사용할것
    batch_for_acc = getMiniBatch(x, y, batch_size)
    x_acc, y_acc = next(batch_for_acc)
    a, c = sess.run([accuracy, cost], feed_dict={X:x_acc, Y:y_acc, keep_prob:1})
    return a, c

# %% [markdown]
# 아래 셀 실행시 모델을 만들고 계산하는데 모두 시간이 좀 걸립니다

# %%
s_time = time.time()
#----------------------
sess = tf.InteractiveSession(config=tf.ConfigProto(log_device_placement=True))
sess.run(tf.global_variables_initializer())

x_range=[]
train_accuracies=[]
val_accuracies=[]
val_costs=[]
X_val_tok = tok_embedding(X_val)

for i in range(total_iter):
    X_, Y_ = getMiniBatch2(X_train, Y_train, batch_size) # 랜덤 미니배치 할당
    train_step.run(feed_dict={X:X_, Y:Y_})

#   아래에 결과 프린트용
    if i % 10 == 0:   
        train_accuracy = accuracy.eval(feed_dict={X:X_, Y:Y_})
        val_accuracy, val_cost = sess.run([accuracy, cost], feed_dict={X:X_val_tok, Y:Y_val})
        
        train_accuracies.append(train_accuracy)
        val_accuracies.append(val_accuracy)
        val_costs.append(val_cost)
        x_range.append(i)
        print('step %d: acc_tr %g, acc_tt %g, val_cost %g' % (i, train_accuracy, val_accuracy, val_cost))
# -------------------------
e_time = time.time()
print('training time: %s sec' %(e_time - s_time))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# step 0: acc_tr 0.35, acc_tt 0.157738, val_cost 1.9546
# step 10: acc_tr 0.22, acc_tt 0.205357, val_cost 1.91706
# step 20: acc_tr 0.33, acc_tt 0.247024, val_cost 1.88304
# step 30: acc_tr 0.36, acc_tt 0.276786, val_cost 1.84469
# step 40: acc_tr 0.37, acc_tt 0.276786, val_cost 1.80718
# step 50: acc_tr 0.36, acc_tt 0.309524, val_cost 1.72315
# step 60: acc_tr 0.43, acc_tt 0.318452, val_cost 1.67172
# step 70: acc_tr 0.44, acc_tt 0.392857, val_cost 1.58422
# step 80: acc_tr 0.47, acc_tt 0.377976, val_cost 1.60351
# step 90: acc_tr 0.43, acc_tt 0.357143, val_cost 1.60365
# step 100: acc_tr 0.35, acc_tt 0.357143, val_cost 1.61119
# step 110: acc_tr 0.48, acc_tt 0.383929, val_cost 1.55381
# step 120: acc_tr 0.51, acc_tt 0.375, val_cost 1.55847
# step 130: acc_tr 0.44, acc_tt 0.425595, val_cost 1.47969
# step 140: acc_tr 0.45, acc_tt 0.389881, val_cost 1.50252
# step 150: acc_tr 0.46, acc_tt 0.404762, val_cost 1.47402
# step 160: acc_tr 0.39, acc_tt 0.377976, val_cost 1.53691
# step 170: acc_tr 0.55, acc_tt 0.389881, val_cost 1.50896
# step 180: acc_tr 0.57, acc_tt 0.416667, val_cost 1.49292
# step 190: acc_tr 0.55, acc_tt 0.404762, val_cost 1.47903
# step 200: acc_tr 0.47, acc_tt 0.434524, val_cost 1.47466
# step 210: acc_tr 0.57, acc_tt 0.375, val_cost 1.55644
# step 220: acc_tr 0.47, acc_tt 0.434524, val_cost 1.50715
# step 230: acc_tr 0.58, acc_tt 0.422619, val_cost 1.47972
# step 240: acc_tr 0.49, acc_tt 0.380952, val_cost 1.47768
# step 250: acc_tr 0.48, acc_tt 0.401786, val_cost 1.47398
# step 260: acc_tr 0.47, acc_tt 0.416667, val_cost 1.43697
# step 270: acc_tr 0.57, acc_tt 0.39881, val_cost 1.47499
# step 280: acc_tr 0.51, acc_tt 0.419643, val_cost 1.44252
# step 290: acc_tr 0.51, acc_tt 0.425595, val_cost 1.4645
# step 300: acc_tr 0.52, acc_tt 0.41369, val_cost 1.46624
# step 310: acc_tr 0.51, acc_tt 0.440476, val_cost 1.45694
# step 320: acc_tr 0.48, acc_tt 0.431548, val_cost 1.43307
# step 330: acc_tr 0.55, acc_tt 0.449405, val_cost 1.45985
# step 340: acc_tr 0.54, acc_tt 0.428571, val_cost 1.44173
# step 350: acc_tr 0.43, acc_tt 0.410714, val_cost 1.46056
# step 360: acc_tr 0.54, acc_tt 0.425595, val_cost 1.47752
# step 370: acc_tr 0.57, acc_tt 0.446429, val_cost 1.42375
# step 380: acc_tr 0.54, acc_tt 0.464286, val_cost 1.43329
# step 390: acc_tr 0.59, acc_tt 0.428571, val_cost 1.43772
# step 400: acc_tr 0.61, acc_tt 0.470238, val_cost 1.4239
# step 410: acc_tr 0.43, acc_tt 0.428571, val_cost 1.48056
# step 420: acc_tr 0.68, acc_tt 0.443452, val_cost 1.45892
# step 430: acc_tr 0.56, acc_tt 0.434524, val_cost 1.44168
# step 440: acc_tr 0.61, acc_tt 0.446429, val_cost 1.42834
# step 450: acc_tr 0.56, acc_tt 0.446429, val_cost 1.44716
# step 460: acc_tr 0.62, acc_tt 0.434524, val_cost 1.47199
# step 470: acc_tr 0.57, acc_tt 0.458333, val_cost 1.46715
# step 480: acc_tr 0.55, acc_tt 0.455357, val_cost 1.47726
# step 490: acc_tr 0.63, acc_tt 0.422619, val_cost 1.5227
# step 500: acc_tr 0.67, acc_tt 0.434524, val_cost 1.49556
# step 510: acc_tr 0.66, acc_tt 0.46131, val_cost 1.47331
# step 520: acc_tr 0.61, acc_tt 0.464286, val_cost 1.45837
# step 530: acc_tr 0.61, acc_tt 0.455357, val_cost 1.50452
# step 540: acc_tr 0.63, acc_tt 0.443452, val_cost 1.51326
# step 550: acc_tr 0.61, acc_tt 0.449405, val_cost 1.51848
# step 560: acc_tr 0.66, acc_tt 0.431548, val_cost 1.47723
# step 570: acc_tr 0.65, acc_tt 0.46131, val_cost 1.49129
# step 580: acc_tr 0.69, acc_tt 0.470238, val_cost 1.43485
# step 590: acc_tr 0.57, acc_tt 0.449405, val_cost 1.46644
# step 600: acc_tr 0.71, acc_tt 0.47619, val_cost 1.44796
# step 610: acc_tr 0.64, acc_tt 0.458333, val_cost 1.48715
# step 620: acc_tr 0.63, acc_tt 0.482143, val_cost 1.4843
# step 630: acc_tr 0.6, acc_tt 0.458333, val_cost 1.47309
# step 640: acc_tr 0.56, acc_tt 0.452381, val_cost 1.48203
# step 650: acc_tr 0.65, acc_tt 0.455357, val_cost 1.49027
# step 660: acc_tr 0.7, acc_tt 0.470238, val_cost 1.47778
# step 670: acc_tr 0.73, acc_tt 0.482143, val_cost 1.48205
# step 680: acc_tr 0.63, acc_tt 0.482143, val_cost 1.47705
# step 690: acc_tr 0.72, acc_tt 0.440476, val_cost 1.51933
# step 700: acc_tr 0.73, acc_tt 0.431548, val_cost 1.5458
# step 710: acc_tr 0.67, acc_tt 0.446429, val_cost 1.52788
# step 720: acc_tr 0.59, acc_tt 0.440476, val_cost 1.52364
# step 730: acc_tr 0.75, acc_tt 0.446429, val_cost 1.53692
# step 740: acc_tr 0.66, acc_tt 0.470238, val_cost 1.54609
# step 750: acc_tr 0.64, acc_tt 0.458333, val_cost 1.51761
# step 760: acc_tr 0.63, acc_tt 0.467262, val_cost 1.4933
# step 770: acc_tr 0.73, acc_tt 0.443452, val_cost 1.5394
# step 780: acc_tr 0.72, acc_tt 0.46131, val_cost 1.53622
# step 790: acc_tr 0.7, acc_tt 0.458333, val_cost 1.55667
# step 800: acc_tr 0.62, acc_tt 0.458333, val_cost 1.60728
# step 810: acc_tr 0.65, acc_tt 0.470238, val_cost 1.61736
# step 820: acc_tr 0.75, acc_tt 0.455357, val_cost 1.6349
# step 830: acc_tr 0.83, acc_tt 0.470238, val_cost 1.62025
# step 840: acc_tr 0.72, acc_tt 0.428571, val_cost 1.61768
# step 850: acc_tr 0.68, acc_tt 0.452381, val_cost 1.56281
# step 860: acc_tr 0.72, acc_tt 0.446429, val_cost 1.52697
# step 870: acc_tr 0.71, acc_tt 0.425595, val_cost 1.62776
# step 880: acc_tr 0.68, acc_tt 0.449405, val_cost 1.54573
# step 890: acc_tr 0.83, acc_tt 0.4375, val_cost 1.59014
# step 900: acc_tr 0.69, acc_tt 0.458333, val_cost 1.58888
# step 910: acc_tr 0.76, acc_tt 0.455357, val_cost 1.67303
# step 920: acc_tr 0.64, acc_tt 0.452381, val_cost 1.57314
# step 930: acc_tr 0.76, acc_tt 0.452381, val_cost 1.60475
# step 940: acc_tr 0.66, acc_tt 0.440476, val_cost 1.64623
# step 950: acc_tr 0.77, acc_tt 0.428571, val_cost 1.61292
# step 960: acc_tr 0.78, acc_tt 0.440476, val_cost 1.60499
# step 970: acc_tr 0.79, acc_tt 0.428571, val_cost 1.66888
# step 980: acc_tr 0.73, acc_tt 0.446429, val_cost 1.6516
# step 990: acc_tr 0.75, acc_tt 0.452381, val_cost 1.62346
# step 1000: acc_tr 0.8, acc_tt 0.440476, val_cost 1.65643
# step 1010: acc_tr 0.7, acc_tt 0.46131, val_cost 1.64586
# step 1020: acc_tr 0.78, acc_tt 0.431548, val_cost 1.69902
# step 1030: acc_tr 0.69, acc_tt 0.4375, val_cost 1.68182
# step 1040: acc_tr 0.75, acc_tt 0.434524, val_cost 1.67396
# step 1050: acc_tr 0.73, acc_tt 0.425595, val_cost 1.69226
# step 1060: acc_tr 0.8, acc_tt 0.455357, val_cost 1.65698
# step 1070: acc_tr 0.84, acc_tt 0.428571, val_cost 1.67829
# step 1080: acc_tr 0.73, acc_tt 0.422619, val_cost 1.71203
# step 1090: acc_tr 0.87, acc_tt 0.425595, val_cost 1.71978
# step 1100: acc_tr 0.8, acc_tt 0.458333, val_cost 1.68762
# step 1110: acc_tr 0.77, acc_tt 0.422619, val_cost 1.72071
# step 1120: acc_tr 0.81, acc_tt 0.449405, val_cost 1.71115
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-a6b0721bd420> in <module>()
#      11
#      12 for i in range(total_iter):
# ---> 13     X_, Y_ = getMiniBatch2(X_train, Y_train, batch_size) # 랜덤 미니배치 할당
#      14     train_step.run(feed_dict={X:X_, Y:Y_})
#      15
#
# <ipython-input-18-725bdc601633> in getMiniBatch2(x, y, n)
#       8     x_ = [x[i] for i in rand_idx]
#       9     y_ = [y[i] for i in rand_idx]
# ---> 10     return tok_embedding(x_), y_
#
# <ipython-input-16-e8aac283fa2c> in tok_embedding(tok_vec)
#       6         for j in i:
#       7             try:
# ----> 8                 temp += list(model[j])
#       9             except:
#      10                 temp += list(mean)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(18,5))
plt.subplot(121)
plt.plot(x_range, train_accuracies,'-b', label='Training')
plt.plot(x_range, val_accuracies,'-g', label='Validation')
plt.legend(loc='lower right', frameon=False)
# plt.ylim(ymax = 1.1, ymin = 0.7)
plt.ylabel('accuracy')
plt.xlabel('step')
plt.title('Bi-LSTM: Accuracy')

plt.subplot(122)
plt.plot(x_range, val_costs,'-r', label='Validatin_cost')
plt.legend(loc='lower right', frameon=False)
# plt.ylim(ymax = 1.1, ymin = 0.7)
plt.ylabel('cost')
plt.xlabel('step')
plt.title('Bi-LSTM: Validation Cost')
plt.show()

# %%
# test set data 예측 정확도

xxx = []
yyy = []
bat = round(len(vec_for_test)/100+0.5)
start = 0
end = bat
for i in range(100):
    X_all_test = tok_embedding(vec_for_test[start:end])
    try:
        xxx.extend(predicted.eval(feed_dict={X:X_all_test}))
        yyy.extend(sess.run(tf.arg_max(label_for_test_onehot[start:end], 1)))
        start += bat
        end += bat
        print('\r%d%% calculated'%(i+1), end='')
    except:
        print('except occured')
        
# 레이블별 정확도 시각적으로 보기
dim = len(label_for_test_onehot[0])
image = np.zeros(dim*dim)

for i, el in enumerate(xxx):
    cell = el+yyy[i]*dim
    image[cell] +=1

dist = image.reshape(dim,dim).round(0)
dist_avg = (dist.T/dist.sum(axis=1)).T
dist_avg = dist_avg.round(2)
acc_test = sum(dist.diagonal())/len(vec_for_test)    
print('\ntest set accuracy: ',acc_test)
print(dist_avg)
plt.title('Confusion Matrix')
plt.imshow(dist_avg, cmap='binary')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# WARNING:tensorflow:From <ipython-input-30-d4476f361f6b>:12: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# 98% calculatedexcept occured
# except occured
#
# test set accuracy:  0.46785714285714286
# [[0.29 0.07 0.06 0.05 0.24 0.2  0.09]
#  [0.08 0.43 0.04 0.18 0.12 0.12 0.04]
#  [0.05 0.02 0.61 0.03 0.06 0.15 0.07]
#  [0.02 0.17 0.01 0.57 0.1  0.11 0.02]
#  [0.15 0.1  0.02 0.1  0.38 0.18 0.06]
#  [0.09 0.12 0.06 0.19 0.18 0.31 0.04]
#  [0.08 0.02 0.02 0.02 0.13 0.04 0.69]]
